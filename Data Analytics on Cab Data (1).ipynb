# %% [markdown]
# # Data Analytocs on Cab Data

# %% [markdown]
# ## We are going to perform analytics on Cab Data dataset

# %% [markdown]
# ### Import the requried libraries

# %%
# Import the numerical python 
# Numpu is used for perfoming numerical operation on the different data structrures 
import numpy as np 

# Import the pandas library 
# pandas is used for converting different data structures into pandas dataframe 
import pandas as pd

# Import the seavorn 
# Seaborn is used to visualize the data structures
import seaborn as sns

#Import the matplotlib 
# Matplotlib is the major library utilized for visualization of any data structure 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset

# %%
# Read the dataset from local
df_cab_data = pd.read_csv('cab_data.csv')

# %% [markdown]
# ### Data Overview

# %%
# Show the first 5 observation (row) of the data
df_cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     01/08/2016  Pink Cab  ATLANTA GA         30.45
# 1        10000012     01/06/2016  Pink Cab  ATLANTA GA         28.62
# 2        10000013     01/02/2016  Pink Cab  ATLANTA GA          9.04
# 3        10000014     01/07/2016  Pink Cab  ATLANTA GA         33.17
# 4        10000015     01/03/2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
# Show me the last 5 observation
df_cab_data.tail()
# Out:
#       Transaction ID Date of Travel     Company           City  KM Travelled  \
# 1993        10002603     01/17/2016  Yellow Cab  WASHINGTON DC         36.63
# 1994        10002604     01/09/2016  Yellow Cab  WASHINGTON DC         45.24
# 1995        10002605     01/10/2016  Yellow Cab  WASHINGTON DC         17.92
# 1996        10002606     01/13/2016  Yellow Cab  WASHINGTON DC         19.04
# 1997        10002607     01/16/2016  Yellow Cab  WASHINGTON DC         10.62
#
#       Price Charged  Cost of Trip
# 1993         581.27      509.8896
# 1994         750.50      570.0240
# 1995         302.97      247.2960
# 1996         259.78      242.1888
# 1997         159.07      149.1048

# %% [markdown]
# ### Check the shape of the data

# %%
df_cab_data.shape
# Out:
# (1998, 7)

# %% [markdown]
# ### Interpritation
#
# - we have 1998 observation(rows) in the data
# - we have 7 attributes(columns)

# %%
# Derive the basic information 
df_cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1998 entries, 0 to 1997
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Transaction ID  1998 non-null   int64
#  1   Date of Travel  1998 non-null   object
#  2   Company         1998 non-null   object
#  3   City            1998 non-null   object
#  4   KM Travelled    1998 non-null   float64
#  5   Price Charged   1998 non-null   float64
#  6   Cost of Trip    1998 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 109.4+ KB

# %% [markdown]
# ### Interpritation
#
# - In the data, we have 4 numerical columns(flot+int)
# - In the data we have 3 categoricl columns
# - memory usage is 59.4 + KB
# - In the data, we have not null values

# %%
# Describe the dataset 
df_cab_data.describe().T
# Out:
#                  count          mean         std          min           25%  \
# Transaction ID  1998.0  1.000128e+07  734.816718  10000011.00  1.000065e+07
# KM Travelled    1998.0  2.284948e+01   12.261001         1.90  1.243000e+01
# Price Charged   1998.0  5.019436e+02  311.829241        22.20  2.447225e+02
# Cost of Trip    1998.0  2.904406e+02  158.754446        19.38  1.559430e+02
#
#                          50%           75%          max
# Transaction ID  1.000131e+07  1.000195e+07  10002607.00
# KM Travelled    2.268000e+01  3.323000e+01        47.60
# Price Charged   4.659200e+02  7.205950e+02      1544.45
# Cost of Trip    2.889196e+02  4.213440e+02       668.16

# %% [markdown]
# ### Interpritation
#
# - Average Transaction ID is 1.000128e+07,min Transaction Id is 10000011.00,max Transaction Id is 10002607.00.
# - Average KM Travelled is 2.284948e+01, min Km Travelled is 1.90, max KM Travelled is 47.60.
# - Average Price Charged is 5.019436e+02, Min Pice Charged is 22.20, max Price Charged is 1544.45.
# - Average Cost of Trip is 2.904406e+02, min cost of Trip is 19.38, max Cost of Trip is 668.16.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Cleaning

# %%
# Show the first 5 observation of the data
df_cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     01/08/2016  Pink Cab  ATLANTA GA         30.45
# 1        10000012     01/06/2016  Pink Cab  ATLANTA GA         28.62
# 2        10000013     01/02/2016  Pink Cab  ATLANTA GA          9.04
# 3        10000014     01/07/2016  Pink Cab  ATLANTA GA         33.17
# 4        10000015     01/03/2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
# To make the data representable we need the rename the colums
df_cab_data.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip'],
#       dtype='object')

# %%
# Find the number of missing records in each column 
df_cab_data.isnull().sum()
# Out:
# Transaction ID    0
# Date of Travel    0
# Company           0
# City              0
# KM Travelled      0
# Price Charged     0
# Cost of Trip      0
# dtype: int64

# %%
# Find the percentage of missing records
df_cab_data.isnull().sum()/len(df_cab_data)*100
# Out:
# Transaction ID    0.0
# Date of Travel    0.0
# Company           0.0
# City              0.0
# KM Travelled      0.0
# Price Charged     0.0
# Cost of Trip      0.0
# dtype: float64

# %%
len(df_cab_data)
# Out:
# 1998

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Univariate Analysis

# %%
df_cab_data.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0        10000011     01/08/2016  Pink Cab  ATLANTA GA         30.45
# 1        10000012     01/06/2016  Pink Cab  ATLANTA GA         28.62
# 2        10000013     01/02/2016  Pink Cab  ATLANTA GA          9.04
# 3        10000014     01/07/2016  Pink Cab  ATLANTA GA         33.17
# 4        10000015     01/03/2016  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
#Segregate the data based on the data type
# Categorical data
df_cat = df_cab_data.select_dtypes(include='object')

# Numericald data 
df_num = df_cab_data.select_dtypes(include='number')

# %%
# Categorical data
df_cat.head()
# Out:
#   Date of Travel   Company        City
# 0     01/08/2016  Pink Cab  ATLANTA GA
# 1     01/06/2016  Pink Cab  ATLANTA GA
# 2     01/02/2016  Pink Cab  ATLANTA GA
# 3     01/07/2016  Pink Cab  ATLANTA GA
# 4     01/03/2016  Pink Cab  ATLANTA GA

# %%
# Numberical data 
df_num.head()
# Out:
#    Transaction ID  KM Travelled  Price Charged  Cost of Trip
# 0        10000011         30.45         370.95       313.635
# 1        10000012         28.62         358.52       334.854
# 2        10000013          9.04         125.20        97.632
# 3        10000014         33.17         377.40       351.602
# 4        10000015          8.73         114.62        97.776

# %%
## Univariate analysis on numerical data
df_num.columns
# Out:
# Index(['Transaction ID', 'KM Travelled', 'Price Charged', 'Cost of Trip'], dtype='object')

# %% [markdown]
# ### Copied the interpretations from describe code

# %% [markdown]
# ### Interpritation
#
# - Average Transaction ID is 1.000128e+07,min Transaction Id is 10000011.00,max Transaction Id is 10002607.00.
# - Average KM Travelled is 2.284948e+01, min Km Travelled is 1.90, max KM Travelled is 47.60.
# - Average Price Charged is 5.019436e+02, Min Pice Charged is 22.20, max Price Charged is 1544.45.
# - Average Cost of Trip is 2.904406e+02, min cost of Trip is 19.38, max Cost of Trip is 668.16.

# %% [markdown]
# ### Univeriate Analysis on Categorical Data

# %%
# Show the data in categorical data from
df_cat.head()
# Out:
#   Date of Travel   Company        City
# 0     01/08/2016  Pink Cab  ATLANTA GA
# 1     01/06/2016  Pink Cab  ATLANTA GA
# 2     01/02/2016  Pink Cab  ATLANTA GA
# 3     01/07/2016  Pink Cab  ATLANTA GA
# 4     01/03/2016  Pink Cab  ATLANTA GA

# %%
df_cat.columns
# Out:
# Index(['Date of Travel', 'Company', 'City'], dtype='object')

# %% [markdown]
# ### Company

# %%
#Show the count of each category present in the Company 
df_cat.Company.value_counts()
# Out:
# Company
# Yellow Cab    1544
# Pink Cab       454
# Name: count, dtype: int64

# %%
# Do the visualization of that count 
df_cat.Company.value_counts().plot(kind='bar',color='green')
plt.xticks(rotation=0)
plt.title('count fo Company')
plt.grid()
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Interpretation
#
# - we have 1544 yellow cabs  present in the company
# - we have 454 pink cabs present in the company

# %% [markdown]
# ### City

# %%
# show the count of city avallable 
df_cat.City.value_counts()
# Out:
# City
# NEW YORK NY       462
# CHICAGO IL        418
# LOS ANGELES CA    307
# WASHINGTON DC     188
# BOSTON MA         145
# SAN DIEGO CA      122
# SEATTLE WA         77
# ATLANTA GA         56
# DALLAS TX          55
# SILICON VALLEY     49
# DENVER CO          22
# ORANGE COUNTY      20
# MIAMI FL           15
# AUSTIN TX          14
# SACRAMENTO CA      13
# PHOENIX AZ         12
# NASHVILLE TN        9
# TUCSON AZ           9
# PITTSBURGH PA       5
# Name: count, dtype: int64

# %%
# Do the visualization of the count
df_cat.City.value_counts().plot(kind='bar',color='purple')
plt.xticks(rotation= 0)
plt.title('count of City')
plt.grid()
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### Interpretation
# - we have 462 NEW YORK NY where present is city.
# - we have 418 CHICAGO IL where  present is city.
# - we have 307 LOS ANGELES CA where present is city.
# - we have 188 WASHINGTON DC where present is city.
# - we have 145 BOSTON MA where present is city.
# - we have 122 SAN DIEGO CA where present is city.
# - we have 77 SEATTLE WA where present is city.
# - we have 20 ORANGE COUNTY where present is city.
# - we have 15 MIAMI FL where present is city.
# - we have 14 AUSTIN TX where present is city.
# - we have 13 SACRAMENTO CA where present is city.
# - we have 12 PHOENIX AZ where present is city.
# - we have 9 NASHVILLE TN where present is city.
# - we have 9 TUCSON AZ where present is city.
# - we have 5 PITTSBURGH PA where present is city.

# %% [markdown]
# ## Bivariate Analysis

# %%
# Show the first 5 of observation of the data.
df_num.head()
# Out:
#    Transaction ID  KM Travelled  Price Charged  Cost of Trip
# 0        10000011         30.45         370.95       313.635
# 1        10000012         28.62         358.52       334.854
# 2        10000013          9.04         125.20        97.632
# 3        10000014         33.17         377.40       351.602
# 4        10000015          8.73         114.62        97.776

# %%
# To find the pairs in Bivariate Analysis, we have to use following step.
# step 1: Find the correlation 
df_num.corr()
# Out:
#                 Transaction ID  KM Travelled  Price Charged  Cost of Trip
# Transaction ID        1.000000      0.019411       0.065813      0.063285
# KM Travelled          0.019411      1.000000       0.879776      0.982567
# Price Charged         0.065813      0.879776       1.000000      0.907787
# Cost of Trip          0.063285      0.982567       0.907787      1.000000

# %% [raw]
# # Pairs for Bivariate Analysis
# # acceptance criteria (0.7,0.8,0.9,1)(-0.7,-0.8,-0.9,-1)
# # (KM Travelled, Cost of Trip)
# # (Price Charged, Cost of Trip)
# # (KM Travelled,price Charged )

# %% [markdown]
# ### KM Travelle, Cost of Trip

# %%
sns.scatterplot(x='KM Travelled',y='Cost of Trip',data=df_num,color='red')
plt.title('scatter plot between KM Travelle and Cost of Trip')
plt.show()

# %% [markdown]
# ### Interpretation
#
# - it is easy to see that there is a positive correlation
# - it means when cost of trip is increase and KM Travelled is increase

# %% [markdown]
# ### Price Charged, Cost of Trip

# %%
sns.scatterplot(x='Price Charged',y='Cost of Trip',data=df_num)
plt.title('scatter plot between Price Charged and Cost of Trip')
plt.show()

# %% [markdown]
# ### Interpretation
#
# - it is directly showing that Positive correlation
# - when cost of Trip increased and price charged increased

# %% [markdown]
# ### KM Travelled,price Charged

# %%
sns.scatterplot(x='KM Travelled',y='Price Charged',data=df_num)
plt.title('scatter plot between KM Travelled and Price Charged')
plt.show()

# %% [markdown]
# ### Interpritation
#
# - It is directly showing that Positive correlation
# - when cost of Price Charged  and KM Travelled increased

# %%
# Find the pair having dtrong positive or negative relation 
# # (KM Travelled, Cost of Trip)
# (Price Charged, Cost of Trip)
# (KM Travelled,price Charged )

# %%
# Numrical variable with linear relationsheep 
# KM Travelled, Cost of Trip, Price Charged,

# %%
# show the categorical data 
df_cat.columns
# Out:
# Index(['Date of Travel', 'Company', 'City'], dtype='object')

# %%
df_cat.head()
# Out:
#   Date of Travel   Company        City
# 0     01/08/2016  Pink Cab  ATLANTA GA
# 1     01/06/2016  Pink Cab  ATLANTA GA
# 2     01/02/2016  Pink Cab  ATLANTA GA
# 3     01/07/2016  Pink Cab  ATLANTA GA
# 4     01/03/2016  Pink Cab  ATLANTA GA

# %%
# Pairs for 1 Categorical and 1 Numerical column
# Date of Travel,KM Travelled
#Date of Trave, Cost of Trip
#Date of Travel,Price Charged
#Company,KM Travelled
#Company,Cost of Trip
#Company,Price Charged
#City,KM Travelled
#City,Cost of Trip
#City,Price Charged

# %% [markdown]
# ### Date of Travel,KM Travelled

# %%
df_cab_data.groupby('Date of Travel')['KM Travelled'].mean()
# Out:
# Date of Travel
# 01/02/2016    22.618564
# 01/03/2016    23.426011
# 01/04/2016    21.138800
# 01/05/2016    26.443191
# 01/06/2016    22.343394
# 01/07/2016    22.237234
# 01/08/2016    22.188018
# 01/09/2016    23.205611
# 01/10/2016    22.984784
# 01/11/2016    22.113415
# 01/12/2016    22.597531
# 01/13/2016    22.462529
# 01/14/2016    22.325905
# 01/15/2016    24.012165
# 01/16/2016    24.186190
# 01/17/2016    23.026024
# 01/18/2016    20.136066
# 01/19/2016    22.333333
# Name: KM Travelled, dtype: float64

# %%
# visualize the graph
sns.barplot(x='KM Travelled',y='Date of Travel', data=df_cab_data,color='purple')
plt.title('KM Travelled vs Date of Travel')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpritation
#
# - When we have 01/02/2016 as a Date of Travel avg KM Travelled of the cab is 22.618564
# - When we have 01/03/2016 as a Date of Travel avg KM Travelled of the cab is 23.426011
# - When we have 01/04/2016 as a Date of Travel avg KM Travelled of the cab is 21.138800
# - When we have 01/05/2016 as a Date of Travel avg KM Travelled of the cab is 26.443191
# - When we have 01/06/2016 as a Date of Travel avg KM Travelled of the cab is 22.343394
# - When we have 01/07/2016 as a Date of Travel avg KM Travelled of the cab is 22.237234
# - When we have 01/08/2016 as a Date of Travel avg KM Travelled of the cab is 22.188018
# - When we have 01/09/2016 as a Date of Travel avg KM Travelled of the cab is 23.205611
# - When we have 01/10/2016 as a Date of Travel avg KM Travelled of the cab is 22.984784
# - When we have 01/11/2016 as a Date of Travel avg KM Travelled of the cab is 22.113415
# - When we have 01/12/2016 as a Date of Travel avg KM Travelled of the cab is 22.597531
# - When we have 01/13/2016 as a Date of Travel avg KM Travelled of the cab is 22.462529
# - When we have 01/14/2016 as a Date of Travel avg KM Travelled of the cab is 22.325905
# - When we have 01/15/2016 as a Date of Travel avg KM Travelled of the cab is 24.012165
# - When we have 01/16/2016 as a Date of Travel avg KM Travelled of the cab is 24.186190
# - When we have 01/17/2016 as a Date of Travel avg KM Travelled of the cab is 23.026024
# - When we have 01/18/2016 as a Date of Travel avg KM Travelled of the cab is 20.136066
# - When we have 01/19/2016 as a Date of Travel avg KM Travelled of the cab is 22.333333

# %% [markdown]
# ### Date of Travel, Cost of Trip

# %%
df_cab_data.groupby('Date of Travel')['Cost of Trip'].mean()
# Out:
# Date of Travel
# 01/02/2016    288.458054
# 01/03/2016    293.688029
# 01/04/2016    278.957912
# 01/05/2016    342.966923
# 01/06/2016    281.249106
# 01/07/2016    284.438213
# 01/08/2016    280.900218
# 01/09/2016    294.770708
# 01/10/2016    290.510144
# 01/11/2016    289.262822
# 01/12/2016    284.093788
# 01/13/2016    285.985034
# 01/14/2016    280.188230
# 01/15/2016    308.317736
# 01/16/2016    312.896760
# 01/17/2016    290.664171
# 01/18/2016    255.329689
# 01/19/2016    282.855689
# Name: Cost of Trip, dtype: float64

# %%
# visualize the graph
df_cab_data.groupby('Date of Travel')['Cost of Trip'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Date of Travel'>

# %% [markdown]
# ### Interpritation
#
# - When we have 01/02/2016 as a Date of Travel avg Cost of Trip of the cab is 288.458054
# - When we have 01/03/2016 as a Date of Travel avg Cost of Trip of the cab is 293.688029
# - When we have 01/04/2016 as a Date of Travel avg Cost of Trip of the cab is 278.957912
# - When we have 01/05/2016 as a Date of Travel avg Cost of Trip of the cab is 342.966923
# - When we have 01/06/2016 as a Date of Travel avg Cost of Trip of the cab is 342.966923
# - When we have 01/07/2016 as a Date of Travel avg Cost of Trip of the cab is 281.249106
# - When we have 01/08/2016 as a Date of Travel avg Cost of Trip of the cab is 284.438213
# - When we have 01/09/2016 as a Date of Travel avg Cost of Trip of the cab is 294.770708
# - When we have 01/10/2016 as a Date of Travel avg Cost of Trip of the cab is 290.510144
# - When we have 01/11/2016 as a Date of Travel avg Cost of Trip of the cab is 289.262822
# - When we have 01/12/2016 as a Date of Travel avg Cost of Trip of the cab is 284.093788
# - When we have 01/13/2016 as a Date of Travel avg Cost of Trip of the cab is 285.985034
# - When we have 01/14/2016 as a Date of Travel avg Cost of Trip of the cab is 280.188230
# - When we have 01/15/2016 as a Date of Travel avg Cost of Trip of the cab is 308.317736
# - When we have 01/16/2016 as a Date of Travel avg Cost of Trip of the cab is 312.896760
# - When we have 01/17/2016 as a Date of Travel avg Cost of Trip of the cab is 290.664171
# - When we have 01/18/2016 as a Date of Travel avg Cost of Trip of the cab is 255.329689
# - When we have 01/19/2016 as a Date of Travel avg Cost of Trip of the cab is 282.855689

# %% [markdown]
# ### Date of Travel,Price Charged

# %%
df_cab_data.groupby('Date of Travel')['Price Charged'].mean()
# Out:
# Date of Travel
# 01/02/2016    565.281602
# 01/03/2016    569.362809
# 01/04/2016    442.109600
# 01/05/2016    600.062128
# 01/06/2016    473.913578
# 01/07/2016    479.060638
# 01/08/2016    487.792342
# 01/09/2016    517.635305
# 01/10/2016    525.516039
# 01/11/2016    476.587073
# 01/12/2016    468.807160
# 01/13/2016    458.433793
# 01/14/2016    437.818857
# 01/15/2016    479.962990
# 01/16/2016    506.626310
# 01/17/2016    443.844699
# 01/18/2016    390.725410
# 01/19/2016    477.141111
# Name: Price Charged, dtype: float64

# %%
# visualize the graph
sns.barplot(x='Price Charged',y='Date of Travel', data=df_cab_data,color='purple')
plt.title('Price Charged, vs Date of Travel')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpritation
# - When we have 01/02/2016 as a Date of Travel avg Price Charged of the cab is 565.281602.
# - When we have 01/03/2016 as a Date of Travel avg Price Charged of the cab is 569.362809
# - When we have 01/04/2016 as a Date of Travel avg Price Charged of the cab is 442.109600.
# - When we have 01/05/2016  as a Date of Travel avg Price Charged of the cab is 600.062128.
# - When we have 01/06/2016 as a Date of Travel avg Price Charged of the cab is 473.913578
# - When we have 01/07/2016 as a Date of Travel avg Price Charged of the cab is 479.060638
# - When we have 01/08/2016 as a Date of Travel avg Price Charged of the cab is 487.792342
# - When we have 01/09/2016 as a Date of Travel avg Price Charged of the cab is 517.635305
# - When we have 01/10/2016 as a Date of Travel avg Price Charged of the cab is 525.516039
# - When we have 01/12/2016 as a Date of Travel avg Price Charged of the cab is 476.587073
# - When we have 01/13/2016 as a Date of Travel avg Price Charged of the cab is 458.433793
# - When we have 01/14/2016 as a Date of Travel avg Price Charged of the cab is 476.587073
# - When we have 01/15/2016 as a Date of Travel avg Price Charged of the cab is 479.962990
# - When we have 01/16/2016 as a Date of Travel avg Price Charged of the cab is 506.626310
# - When we have 01/17/2016 as a Date of Travel avg Price Charged of the cab is 443.844699
# - When we have 01/18/2016 as a Date of Travel avg Price Charged of the cab is 390.725410
# - When we have 01/19/2016 as a Date of Travel avg Price Charged of the cab is 477.141111

# %% [markdown]
# ### Company,KM Travelled

# %%
df_cab_data.groupby('Company')['KM Travelled'].mean()
# Out:
# Company
# Pink Cab      22.370220
# Yellow Cab    22.990408
# Name: KM Travelled, dtype: float64

# %%
# visualize the graph
sns.barplot(x='Company',y='KM Travelled', data=df_cab_data,color='purple')
plt.title('Company, vs KM Travelled')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretation
#
# - This data is Balense Data There is no such a relation between KM Travelled and Company.

# %% [markdown]
# ### Company,Cost of Trip

# %%
df_cab_data.groupby('Company')['KM Travelled'].mean()
# Out:
# Company
# Pink Cab      22.370220
# Yellow Cab    22.990408
# Name: KM Travelled, dtype: float64

# %%
# visualize the graph
sns.barplot(x='Company',y='Cost of Trip', data=df_cab_data,color='purple')
plt.title('Company, vs Cost of Trip')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpritation
# - when we have Pink cab as a company avg cost of Trip of the cab is 22.370220
# - When we have Yellow cab as a company avg Cost of Trip of the cab is 22.990408

# %% [markdown]
# ### Company,Price Charged

# %%
df_cab_data.groupby('Company')['KM Travelled'].mean()
# Out:
# Company
# Pink Cab      22.370220
# Yellow Cab    22.990408
# Name: KM Travelled, dtype: float64

# %%
# visualize the graph
sns.barplot(x='Company',y='KM Travelled', data=df_cab_data,color='purple')
plt.title('Company, vs KM Travelled')
plt.grid()
plt.show()

# %% [markdown]
# ### Interpretation
#
# - This data is Balense Data There is no such a relation between Company and KM Travelled.

# %% [markdown]
# ### City,KM Travelled

# %%
df_cab_data.groupby('City')['KM Travelled'].mean()
# Out:
# City
# ATLANTA GA        20.827143
# AUSTIN TX         27.765714
# BOSTON MA         22.572828
# CHICAGO IL        22.851818
# DALLAS TX         23.818909
# DENVER CO         19.514545
# LOS ANGELES CA    22.663420
# MIAMI FL          24.794000
# NASHVILLE TN      23.810000
# NEW YORK NY       23.277987
# ORANGE COUNTY     18.870000
# PHOENIX AZ        26.499167
# PITTSBURGH PA     22.762000
# SACRAMENTO CA     26.636923
# SAN DIEGO CA      22.175328
# SEATTLE WA        23.726104
# SILICON VALLEY    22.006735
# TUCSON AZ         19.157778
# WASHINGTON DC     22.855957
# Name: KM Travelled, dtype: float64

# %%
# visualize the graph
df_cab_data.groupby('City')['KM Travelled'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# ### Interpretation
# - when ever we have ATLANTA GA as a City avg KM Travelled of the cab is 20.827143
# - when ever we have AUSTIN TX as a City avg KM Travelled of the cab is 27.765714
# - when ever we have BOSTON MA as a City avg KM Travelled of the cab is 22.572828
# - when ever we have CHICAGO IL as a City avg KM Travelled of the cab is 22.851818
# - when ever we have DALLAS TX  as a City avg KM Travelled of the cab is 23.818909
# - when ever we have DENVER CO  as a City avg KM Travelled of the cab is 19.514545
# - when ever we have LOS ANGELES CA as a City avg KM Travelled of the cab is 22.663420
# - when ever we have MIAMI FL as a City avg KM Travelled of the cab is 24.794000
# - when ever we have NASHVILLE TN as a City avg KM Travelled of the cab is 23.810000
# - when ever we have NEW YORK NY as a City avg KM Travelled of the cab is 23.277987
# - when ever we have ORANGE COUNTY as a City avg KM Travelled of the cab is 18.870000
# - when ever we have PHOENIX AZ as a City avg KM Travelled of the cab is 26.499167
# - when ever we have PITTSBURGH PA as a City avg KM Travelled of the cab is 22.762000
# - when ever we have SACRAMENTO CA as a City avg KM Travelled of the cab is 26.636923
# - when ever we have SAN DIEGO CA as a City avg KM Travelled of the cab is 22.175328
# - when ever we have SEATTLE WA as a City avg KM Travelled of the cab is 23.726104
# - when ever we have TUCSON AZ  as a City avg KM Travelled of the cab is 19.157778
# - when ever we have WASHINGTON DC as a City avg KM Travelled of the cab is 22.855957

# %% [markdown]
# ### City,Cost of Trip

# %%
df_cab_data.groupby('City')['Cost of Trip'].mean()
# Out:
# City
# ATLANTA GA        262.353436
# AUSTIN TX         347.348914
# BOSTON MA         289.748335
# CHICAGO IL        294.677972
# DALLAS TX         304.848407
# DENVER CO         250.269136
# LOS ANGELES CA    281.549678
# MIAMI FL          299.958707
# NASHVILLE TN      276.676578
# NEW YORK NY       301.650021
# ORANGE COUNTY     231.596250
# PHOENIX AZ        323.852483
# PITTSBURGH PA     291.431720
# SACRAMENTO CA     321.641031
# SAN DIEGO CA      270.032069
# SEATTLE WA        294.140125
# SILICON VALLEY    269.925641
# TUCSON AZ         235.357822
# WASHINGTON DC     294.695353
# Name: Cost of Trip, dtype: float64

# %%
# visualize the graph
df_cab_data.groupby('City')['KM Travelled'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# ### Interpretation
#
# - when ever we have ATLANTA GA as a city avg Cost of Trip of the cab is 262.353436
# - when ever we have AUSTIN TX as a city avg Cost of Trip of the cab is 347.348914
# - When ever we have BOSTON MA as a city avg Cost of Trip of the cab is 289.748335
# - When ever we have CHICAGO IL as a city avg Cost of Trip of the cab is 294.677972
# - When ever we have DALLAS TX  as a city avg Cost of Trip of the cab is 304.848407
# - When ever we have DENVER CO as a city avg Cost of Trip of the cab is 250.269136
# - When ever we have LOS ANGELES CA as a city avg Cost of Trip of the cab is 281.549678
# - When ever we have MIAMI FL as a city avg Cost of Trip of the cab is 299.958707
# - When ever we have NASHVILLE TN as a city avg Cost of Trip of the cab is 276.676578
# - When ever we have NEW YORK NY as a city avg Cost of Trip of the cab is 301.650021
# - When ever we have ORANGE COUNTY as a city avg Cost of Trip of the cab is 231.596250
# - When ever we have PHOENIX AZ as a city avg Cost of Trip of the cab is 323.852483
# - When ever we have PITTSBURGH PA as a city avg Cost of Trip of the cab is 291.431720
# - When ever we have SACRAMENTO CA as a city avg Cost of Trip of the cab is 321.641031
# - When ever we have SAN DIEGO CA as a city avg Cost of Trip of the cab is 270.032069
# - When ever we have TUCSON AZ as a city avg Cost of Trip of the cab is 235.357822
# - When ever we have SILICON VALLEY as a city avg Cost of Trip of the cab is 269.925641
# - When ever we have  WASHINGTON DC as a city avg Cost of Trip of the cab is 294.695353

# %% [markdown]
# ### #City,Price Charged

# %%
df_cab_data.groupby('City')['Price Charged'].mean()
# Out:
# City
# ATLANTA GA        512.168036
# AUSTIN TX         596.276429
# BOSTON MA         372.451172
# CHICAGO IL        465.411651
# DALLAS TX         590.983636
# DENVER CO         501.423182
# LOS ANGELES CA    510.424300
# MIAMI FL          487.749333
# NASHVILLE TN      553.405556
# NEW YORK NY       614.528680
# ORANGE COUNTY     387.132000
# PHOENIX AZ        566.468333
# PITTSBURGH PA     587.022000
# SACRAMENTO CA     569.881538
# SAN DIEGO CA      452.195902
# SEATTLE WA        449.135195
# SILICON VALLEY    515.105102
# TUCSON AZ         423.780000
# WASHINGTON DC     410.491117
# Name: Price Charged, dtype: float64

# %%
# visualize the graph
df_cab_data.groupby('City')['Price Charged'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %% [markdown]
# ### Interpretation
# - when ever we have ATLANTA GA as a city avg Price Charged of the cab is 512.168036
# - when ever we have AUSTIN TX as a city avg Cost of Trip of the cab is 596.276429
# - When ever we have BOSTON MA as a city avg Cost of Trip of the cab is 372.451172
# - When ever we have CHICAGO IL as a city avg Cost of Trip of the cab is 465.411651
# - When ever we have DALLAS TX  as a city avg Cost of Trip of the cab is 590.983636
# - When ever we have DENVER CO as a city avg Cost of Trip of the cab is 501.423182
# - When ever we have LOS ANGELES CA as a city avg Cost of Trip of the cab is 510.424300
# - When ever we have MIAMI FL as a city avg Cost of Trip of the cab is 487.749333
# - When ever we have NASHVILLE TN as a city avg Cost of Trip of the cab is 553.405556
# - When ever we have NEW YORK NY as a city avg Cost of Trip of the cab is 614.528680
# - When ever we have ORANGE COUNTY as a city avg Cost of Trip of the cab is 387.132000
# - When ever we have PHOENIX AZ as a city avg Cost of Trip of the cab is 566.468333
# - When ever we have PITTSBURGH PA as a city avg Cost of Trip of the cab is 587.022000
# - When ever we have SACRAMENTO CA as a city avg Cost of Trip of the cab is 569.881538
# - When ever we have SAN DIEGO CA as a city avg Cost of Trip of the cab is 452.195902
# - When ever we have TUCSON AZ as a city avg Cost of Trip of the cab is 423.780000
# - When ever we have SILICON VALLEY as a city avg Cost of Trip of the cab is 515.105102
# - When ever we have  WASHINGTON DC as a city avg Cost of Trip of the cab is 410.491117

# %% [markdown]
# ### Multivariate Analysis

# %%
# Categorical Columns : Date of Travel, Company, City
# Numerical Columns : KM Travelled, Cost of Trip, Price Charged

# %%
# map the Pair 
# Date of Travel, Company,KM Travelled
# Date of Travel,City,KM Travelled
# Company, City,KM Travelled

# Date of Travel, Company,Cost of Trip
# Date of Travel,City,Cost of Trip
# Company, City,Cost of Trip

# Date of Travel, Company,Price Charged
# Date of Travel,City,Price Charged
# Company, City,Price Charged

# %% [markdown]
# ### Date of Travel, Company,KM Travelled

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['KM Travelled'],
            aggfunc='min')
# Out:
# Company         Pink Cab  Yellow Cab
# Date of Travel
# 01/02/2016          2.08        1.92
# 01/03/2016          3.57        2.14
# 01/04/2016          2.40        4.76
# 01/05/2016          7.84        3.12
# 01/06/2016          1.96        2.16
# 01/07/2016          5.00        2.36
# 01/08/2016          4.28        2.22
# 01/09/2016          2.10        1.90
# 01/10/2016          2.08        1.90
# 01/11/2016          3.84        1.96
# 01/12/2016          5.30        2.40
# 01/13/2016          3.00        2.85
# 01/14/2016          1.90        2.00
# 01/15/2016          2.94        1.94
# 01/16/2016          4.95        2.26
# 01/17/2016          5.70        2.10
# 01/18/2016          4.52        2.12
# 01/19/2016         28.28       10.50

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab  the mninimum Km Travelled from the cab data is 2.08
# - When we have Date of Travel 1/02/2016 is Yellow cab the minimum KM Travelled from the cabe data is 1.92
# - When we have Date of Travel 1/03/2016 is Pink cab the minimum KM Travelled from the cabe data is 3.57
# - when we have Date of Travel 1/03/2016 is yellow Cab the minimum KM Travelled from the cab data is 2.14
# - when we have Date of Travel 1/04/2016 is Pink Cab the minimum KM Travelled from the cab data is 2.40
# - when we have Date of Travel 1/04/2016 is Yellow Cab the minimum KM Travelled from the cab data is 4.76
# - when we have Date of Travel 1/05/2016 is Pink Cab the minimum KM Travelled from the cab data is 7.84
# - when we have Date of Travel 1/05/2016 is Yellow Cab the minimum KM Travelled from the cab data is 3.12
# - when we have Date of Travel 1/06/2016 is Pink Cab the minimum KM Travelled from the cab data is 1.96
# - when we have Date of Travel 1/06/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.16
# - when we have Date of Travel 1/07/2016 is Pink Cab the minimum KM Travelled from the cab data is 5.00
# - when we have Date of Travel 1/07/2016 is Yellow Cab the minimum KM Travelled from the cab data is 3.26
# - when we have Date of Travel 1/08/2016 is Pink Cab the minimum KM Travelled from the cab data is 4.28
# - when we have Date of Travel 1/08/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.22
# - when we have Date of Travel 1/09/2016 is Pink Cab the minimum KM Travelled from the cab data is 2.10
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the minimum KM Travelled from the cab data is 1.90
# - when we have Date of Travel 1/10/2016 is Pink Cab the minimum KM Travelled from the cab data is 2.08
# - when we have Date of Travel 1/10/2016 is Yellow Cab the minimum KM Travelled from the cab data is 1.90
# - when we have Date of Travel 1/11/2016 is Pink Cab the minimum KM Travelled from the cab data is 3.84
# - when we have Date of Travel 1/11/2016 is Yellow Cab the minimum KM Travelled from the cab data is 1.96
# - when we have Date of Travel 1/12/2016 is Pink Cab the minimum KM Travelled from the cab data is 5.30
# - when we have Date of Travel 1/12/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.40
# - when we have Date of Travel 1/13/2016 is Pink Cab the minimum KM Travelled from the cab data is 3.00
# - when we have Date of Travel 1/13/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.85
# - when we have Date of Travel 1/14/2016 is Pink Cab the minimum KM Travelled from the cab data is 1.90
# - when we have Date of Travel 1/14/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.00
# - when we have Date of Travel 1/15/2016 is Pink Cab the minimum KM Travelled from the cab data is 2.94
# - when we have Date of Travel 1/15/2016 is Yellow Cab the minimum KM Travelled from the cab data is 1.94
# - when we have Date of Travel 1/16/2016 is Pink Cab the minimum KM Travelled from the cab data is 4.95
# - when we have Date of Travel 1/16/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.26
# - when we have Date of Travel 1/17/2016 is Pink Cab the minimum KM Travelled from the cab data is 5.70
# - when we have Date of Travel 1/17/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.10
# - when we have Date of Travel 1/18/2016 is Pink Cab the minimum KM Travelled from the cab data is 4.52
# - when we have Date of Travel 1/18/2016 is Yellow Cab the minimum KM Travelled from the cab data is 2.12
# - when we have Date of Travel 1/19/2016 is Pink Cab the minimum KM Travelled from the cab data is 28.28
# - when we have Date of Travel 1/19/2016 is Yellow Cab the minimum KM Travelled from the cab data is 10.50

# %% [markdown]
# # Draw the syntax
# pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['KM Travelled'],
#             aggfunc='max')

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab  the maximum Km Travelled from the cab data is 46.00
# - When we have Date of Travel 1/02/2016 is Yellow cab the maximum KM Travelled from the cabe data is 46.80
# - When we have Date of Travel 1/03/2016 is Pink cab the maximum KM Travelled from the cabe data is 46.00
# - when we have Date of Travel 1/03/2016 is yellow Cab the maximum KM Travelled from the cab data is 46.41
# - when we have Date of Travel 1/04/2016 is Pink Cab the maximum KM Travelled from the cab data is 36.63
# - when we have Date of Travel 1/04/2016 is Yellow Cab the maximum KM Travelled from the cab data is 39.60
# - when we have Date of Travel 1/05/2016 is Pink Cab the maximum KM Travelled from the cab data is 43.29
# - when we have Date of Travel 1/05/2016 is Yellow Cab the maximum KM Travelled from the cab data is 46.41
# - when we have Date of Travel 1/06/2016 is Pink Cab the maximum KM Travelled from the cab data is 40.68
# - when we have Date of Travel 1/06/2016 is Yellow Cab the maximum KM Travelled from the cab data is 41.65
# - when we have Date of Travel 1/07/2016 is Pink Cab the maximum KM Travelled from the cab data is 38.76
# - when we have Date of Travel 1/07/2016 is Yellow Cab the maximum KM Travelled from the cab data is 46.41
# - when we have Date of Travel 1/08/2016 is Pink Cab the maximum KM Travelled from the cab data is 43.29
# - when we have Date of Travel 1/08/2016 is Yellow Cab the maximum KM Travelled from the cab data is 46.40
# - when we have Date of Travel 1/09/2016 is Pink Cab the maximum KM Travelled from the cab data is 47.60
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the maximum KM Travelled from the cab data is 46.80
# - when we have Date of Travel 1/10/2016 is Pink Cab the maximum KM Travelled from the cab data is 44.84
# - when we have Date of Travel 1/10/2016 is Yellow Cab the maximum KM Travelled from the cab data is 46.80
# - when we have Date of Travel 1/11/2016 is Pink Cab the maximum KM Travelled from the cab data is 39.60
# - when we have Date of Travel 1/11/2016 is Yellow Cab the maximum KM Travelled from the cab data is 44.07
# - when we have Date of Travel 1/12/2016 is Pink Cab the maximum KM Travelled from the cab data is 36.75
# - when we have Date of Travel 1/12/2016 is Yellow Cab the maximum KM Travelled from the cab data is 46.41
# - when we have Date of Travel 1/13/2016 is Pink Cab the maximum KM Travelled from the cab data is 45.20
# - when we have Date of Travel 1/13/2016 is Yellow Cab the maximum KM Travelled from the cab data is 41.60
# - when we have Date of Travel 1/14/2016 is Pink Cab the maximum KM Travelled from the cab data is 42.90
# - when we have Date of Travel 1/14/2016 is Yellow Cab the maximum KM Travelled from the cab data is 46.80
# - when we have Date of Travel 1/15/2016 is Pink Cab the maximum KM Travelled from the cab data is 40.68
# - when we have Date of Travel 1/15/2016 is Yellow Cab the maximum KM Travelled from the cab data is 44.80
# - when we have Date of Travel 1/16/2016 is Pink Cab the maximum KM Travelled from the cab data is 41.60
# - when we have Date of Travel 1/16/2016 is Yellow Cab the maximum KM Travelled from the cab data is 44.40
# - when we have Date of Travel 1/17/2016 is Pink Cab the maximum KM Travelled from the cab data is 45.22
# - when we have Date of Travel 1/17/2016 is Yellow Cab the maximum KM Travelled from the cab data is47.60
# - when we have Date of Travel 1/18/2016 is Pink Cab the maximum KM Travelled from the cab data is 44.80
# - when we have Date of Travel 1/18/2016 is Yellow Cab the maximum KM Travelled from the cab data is 43.68
# - when we have Date of Travel 1/19/2016 is Pink Cab the maximum KM Travelled from the cab data is 28.28
# - when we have Date of Travel 1/19/2016 is Yellow Cab the maximum KM Travelled from the cab data is 27.84

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['KM Travelled'],
            aggfunc='mean')
# Out:
# Company          Pink Cab  Yellow Cab
# Date of Travel
# 01/02/2016      19.865610   23.424786
# 01/03/2016      25.811731   22.441429
# 01/04/2016      19.825000   21.389048
# 01/05/2016      26.363333   26.454878
# 01/06/2016      22.131304   22.400116
# 01/07/2016      21.701667   22.347094
# 01/08/2016      26.410000   21.202889
# 01/09/2016      23.956491   22.996829
# 01/10/2016      21.711642   23.438511
# 01/11/2016      18.228462   22.845362
# 01/12/2016      21.007273   23.190508
# 01/13/2016      22.056250   22.554085
# 01/14/2016      22.844483   22.128026
# 01/15/2016      23.222917   24.271644
# 01/16/2016      20.993333   24.880290
# 01/17/2016      20.223636   24.036721
# 01/18/2016      17.485882   21.160000
# 01/19/2016      28.280000   21.590000

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab  the Average Km Travelled from the cab data is 19.865610
# - When we have Date of Travel 1/02/2016 is Yellow cab the Average KM Travelled from the cabe data is 23.424786
# - When we have Date of Travel 1/03/2016 is Pink cab the Average KM Travelled from the cabe data is 25.811731
# - when we have Date of Travel 1/03/2016 is yellow Cab the Average KM Travelled from the cab data is 22.441429
# - when we have Date of Travel 1/04/2016 is Pink Cab the Average KM Travelled from the cab data is 19.825000
# - when we have Date of Travel 1/04/2016 is Yellow Cab the Average KM Travelled from the cab data is 21.389048
# - when we have Date of Travel 1/05/2016 is Pink Cab the Average KM Travelled from the cab data is 26.363333
# - when we have Date of Travel 1/05/2016 is Yellow Cab the Average KM Travelled from the cab data is 26.454878
# - when we have Date of Travel 1/06/2016 is Pink Cab the Average KM Travelled from the cab data is 22.131304
# - when we have Date of Travel 1/06/2016 is Yellow Cab the Average KM Travelled from the cab data is 22.400116
# - when we have Date of Travel 1/07/2016 is Pink Cab the Average KM Travelled from the cab data is 21.701667
# - when we have Date of Travel 1/07/2016 is Yellow Cab the Average KM Travelled from the cab data is 22.347094
# - when we have Date of Travel 1/08/2016 is Pink Cab the Average KM Travelled from the cab data is 26.410000
# - when we have Date of Travel 1/08/2016 is Yellow Cab the Average KM Travelled from the cab data is 21.202889
# - when we have Date of Travel 1/09/2016 is Pink Cab the Average KM Travelled from the cab data is 23.956491
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the Average KM Travelled from the cab data is 22.996829
# - when we have Date of Travel 1/10/2016 is Pink Cab the Average KM Travelled from the cab data is 21.711642
# - when we have Date of Travel 1/10/2016 is Yellow Cab the Average KM Travelled from the cab data is 23.438511
# - when we have Date of Travel 1/11/2016 is Pink Cab the Average KM Travelled from the cab data is 18.228462
# - when we have Date of Travel 1/11/2016 is Yellow Cab the Average KM Travelled from the cab data is 22.845362
# - when we have Date of Travel 1/12/2016 is Pink Cab the Average KM Travelled from the cab data is 21.007273
# - when we have Date of Travel 1/12/2016 is Yellow Cab the Average KM Travelled from the cab data is 23.190508
# - when we have Date of Travel 1/13/2016 is Pink Cab the Average KM Travelled from the cab data is 22.056250
# - when we have Date of Travel 1/13/2016 is Yellow Cab the Average KM Travelled from the cab data is 22.554085
# - when we have Date of Travel 1/14/2016 is Pink Cab the Average KM Travelled from the cab data is 22.844483
# - when we have Date of Travel 1/14/2016 is Yellow Cab the Average KM Travelled from the cab data is 22.128026
# - when we have Date of Travel 1/15/2016 is Pink Cab the Average KM Travelled from the cab data is 23.222917
# - when we have Date of Travel 1/15/2016 is Yellow Cab the Average KM Travelled from the cab data is 24.271644
# - when we have Date of Travel 1/16/2016 is Pink Cab the Average KM Travelled from the cab data is 20.993333
# - when we have Date of Travel 1/16/2016 is Yellow Cab the Average KM Travelled from the cab data is 24.880290
# - when we have Date of Travel 1/17/2016 is Pink Cab the Average KM Travelled from the cab data is 20.223636	24.036721
# - when we have Date of Travel 1/17/2016 is Yellow Cab the Average KM Travelled from the cab data is 24.036721
# - when we have Date of Travel 1/18/2016 is Pink Cab the Average KM Travelled from the cab data is 17.485882
# - when we have Date of Travel 1/18/2016 is Yellow Cab the Average KM Travelled from the cab data is 21.160000
# - when we have Date of Travel 1/19/2016 is Pink Cab the Average KM Travelled from the cab data is 28.280000
# - when we have Date of Travel 1/19/2016 is Yellow Cab the Average KM Travelled from the cab data is 21.590000

# %% [markdown]
# ####  Date of Travel,City,KM Travelled

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['KM Travelled'],
            aggfunc='min')
# Out:
# City            ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Date of Travel
# 01/02/2016            9.04        NaN       7.91        2.18       5.95
# 01/03/2016            2.14      22.68       2.88        7.49       2.22
# 01/04/2016             NaN      15.82      17.12        6.42        NaN
# 01/05/2016           36.30        NaN        NaN        5.00      15.26
# 01/06/2016           11.88      26.73       1.96        4.52       9.45
# 01/07/2016            6.06      35.65       6.65        4.16      21.60
# 01/08/2016           18.90        NaN       3.03        2.22      12.76
# 01/09/2016            4.60        NaN       3.18        1.90       4.28
# 01/10/2016            2.04      26.50       3.45        1.94       3.21
# 01/11/2016            9.28        NaN       9.50        4.28       4.52
# 01/12/2016            6.60        NaN       5.30        2.40       7.84
# 01/13/2016           15.82        NaN       4.76        3.80        NaN
# ...

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['KM Travelled'],
            aggfunc='max')
# Out:
# City            ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Date of Travel
# 01/02/2016           38.85        NaN      45.24       41.80      45.60
# 01/03/2016           24.75      44.00      43.29       41.20      45.22
# 01/04/2016             NaN      15.82      17.12       38.48        NaN
# 01/05/2016           36.30        NaN        NaN       46.41      46.40
# 01/06/2016           40.95      26.73      32.67       39.20      34.56
# 01/07/2016           46.02      35.65      46.41       45.20      41.34
# 01/08/2016           30.45        NaN      38.22       40.33      43.60
# 01/09/2016           42.18        NaN      46.41       42.84      42.80
# 01/10/2016           26.60      35.34      46.02       44.84      42.56
# 01/11/2016           25.65        NaN      39.60       44.07      20.34
# 01/12/2016            6.60        NaN      40.25       38.42       8.56
# 01/13/2016           19.40        NaN      38.88       45.20        NaN
# ...

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['KM Travelled'],
            aggfunc='mean')
# Out:
# City            ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Date of Travel
# 01/02/2016       26.198000        NaN  27.905000   20.965429  24.337143
# 01/03/2016       12.760000  33.333333  19.431000   20.864839  22.543750
# 01/04/2016             NaN  15.820000  17.120000   24.032500        NaN
# 01/05/2016       36.300000        NaN        NaN   35.565000  33.163333
# 01/06/2016       25.402000  26.730000  17.716667   23.963462  22.076667
# 01/07/2016       22.548333  35.650000  24.255000   23.728621  31.572500
# 01/08/2016       24.675000        NaN  26.252857   18.871000  28.180000
# 01/09/2016       24.914286        NaN  24.520455   22.057869  25.478000
# 01/10/2016       13.185000  31.723333  23.405714   21.150588  21.766000
# 01/11/2016       17.890000        NaN  24.212857   24.776000   9.920000
# 01/12/2016        6.600000        NaN  22.152500   20.862000   8.200000
# 01/13/2016       17.610000        NaN  17.642000   29.158421        NaN
# ...

# %% [markdown]
# ### Company, City,KM Travelled

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['KM Travelled'],
            aggfunc='min')
# Out:
# City        ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Company
# Pink Cab          6.06       3.88       1.96        2.32       3.21
# Yellow Cab        2.04      11.77       2.16        1.90       2.22
#
# City        DENVER CO  LOS ANGELES CA  MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab         3.84            1.90      6.42          5.95          2.1
# Yellow Cab       2.12            1.92      4.28          8.48          1.9
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab             3.51        4.44          12.65          12.43
# Yellow Cab           3.27       12.84           3.09           2.85
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab             2.1        2.08            3.92        5.4           2.94
# Yellow Cab           2.0        2.34            3.80        6.3           3.39

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA  the mninimum KM Travelled from the cab data is 6.06.
# - when we have Company Yellow cab is Atlanta Ga the minimum KM Travelled from the cab data is 2.04
# - When we have Company Pink cab is Austin Tx the minimum KM Travelled From the cab data is 3.88
# - When we have Company Yellow cab is Austlin Tx the minimum KM Travelled from the cab data is 11.77
# - When we have Company Pink cab is Boston MA the minimum KM Travelled from the cab data is 1.96
# - When we have Company Yellow cab is Boston GA  the mninimum KM Travelled from the cab data is 2.16
# - when we have Company Pink cab is Chicago IL the minimum KM Travelled from the cab data is 2.32
# - When we have Company Yellow cab is Chicago IL  the minimum KM Travelled From the cab data is 1.90
# - When we have Company Pink cab is  Dallas Tx the minimum KM Travelled from the cab data is 3.21
# - When we have Company Yellow cab is Dallas Tx the minimum KM Travelled from the cab data is 2.22
# - When we have Company Pink cab is Denver CO the minimum KM Travelled From the cab data is 3.84
# - When we have Company Yellow cab is  Denver CO the minimum KM Travelled from the cab data is 2.12
# - When we have Company Pink cab is LOS Angeles CA the minimum KM Travelled From the cab data is 1.90
# - When we have Company Yellow cab is  LOS Angeles CA the minimum KM Travelled from the cab data is 1.92
# - When we have Company Pink cab is Miami FL  the minimum KM Travelled From the cab data is 6.42
# - When we have Company Yellow cab is  Miami FL  the minimum KM Travelled from the cab data is 4.28
# - When we have Company Pink cab is Nashville TN the minimum KM Travelled From the cab data is 5.95
# - When we have Company Yellow cab is  Nashville TN the minimum KM Travelled from the cab data is 8.48
# - When we have Company Pink cab is New York NY  the minimum KM Travelled From the cab data is 2.1
# - When we have Company Yellow cab is  New York NY  the minimum KM Travelled from the cab data is 1.9
# - When we have Company Pink cab is Orange County  the minimum KM Travelled From the cab data is 3.51
# - When we have Company Yellow cab is  Orange County  the minimum KM Travelled from the cab data is 3.27 -
# - When we have Company Pink cab is  Phoenix Az  the minimum KM Travelled from the cab data is 4.44
# - When we have Company Yellow cab is   Phoenix Az  the minimum KM Travelled From the cab data is 12.84
# - When we have Company Pink cab is  Pittsburgh Pa the minimum KM Travelled from the cab data is 12.65
# - When we have Company Yellow cab is Pittsburgh Pa  the minimum KM Travelled From the cab data is 3.09
# - When we have Company Pink cab is  Sacramento ca the minimum KM Travelled from the cab data is 12.43
# - When we have Company Yellow cab is Sacramento ca the minimum KM Travelled From the cab data is 2.1
# - When we have Company Pink cab is  San Diego ca the minimum KM Travelled from the cab data is 2.0
# - When we have Company Yellow cab is San Diego ca the minimum KM Travelled From the cab data is 2.1
# - When we have Company Pink cab is  Seattle WA  the minimum KM Travelled from the cab data is 2.08
# - When we have Company Yellow cab is Seattle WA   the minimum KM Travelled From the cab data is 2.34
# - When we have Company Pink cab is  Silicon Valley the minimum KM Travelled from the cab data is 3.92
# - When we have Company Yellow cab is Silicon Valley  the minimum KM Travelled From the cab data is 3.80
# - When we have Company Pink cab is  Tucson AZ the minimum KM Travelled from the cab data is 5.4
# - When we have Company Yellow cab is Tucson AZ the minimum KM Travelled From the cab data is 6.3
# - When we have Company Pink cab is  Washington DC the minimum KM Travelled from the cab data is 2.94
# - When we have Company Pink cab is  Washington DC the minimum KM Travelled from the cab data is 3.39

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['KM Travelled'],
            aggfunc='max')
# Out:
# City        ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Company
# Pink Cab         41.44      44.00      44.84        45.2      37.76
# Yellow Cab       46.02      44.03      46.41        47.2      47.60
#
# City        DENVER CO  LOS ANGELES CA  MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab        28.60            46.0     43.32         36.58        45.22
# Yellow Cab      41.81            46.8     42.92         41.40        46.80
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab             39.2        41.3          28.35          47.60
# Yellow Cab           42.4        37.8          38.52          44.84
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab           44.03       46.00           39.78      39.00          43.29
# Yellow Cab         46.80       46.02           43.60      38.88          45.24

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Maximum KM Travelled from the cab data is 41.44
# - when we have Company Yellow cab is Atlanta Ga the Maximum KM Travelled from the cab data is 46.02
# - When we have Company Pink cab is Austin Tx the Maximum KM Travelled From the cab data is 44.00
# - When we have Company Yellow cab is Austlin Tx the Maximum KM Travelled from the cab data is 44.03
# - When we have Company Pink cab is Boston MA the Maximum KM Travelled from the cab data is 44.84
# - When we have Company Yellow cab is Boston GA the Maximum KM Travelled from the cab data is 46.41
# - when we have Company Pink cab is Chicago IL the Maximum KM Travelled from the cab data is 45.2
# - When we have Company Yellow cab is Chicago IL the Maximum KM Travelled From the cab data is 47.2
# - When we have Company Pink cab is Dallas Tx the Maximum KM Travelled from the cab data is 37.76
# - When we have Company Yellow cab is Dallas Tx the Maximum KM Travelled from the cab data is 47.60
# - When we have Company Pink cab is Denver CO the Maximum KM Travelled From the cab data is 28.60
# - When we have Company Yellow cab is Denver CO the Maximum KM Travelled from the cab data is 41.81
# - When we have Company Pink cab is LOS Angeles CA the Maximum KM Travelled From the cab data is 46.0
# - When we have Company Yellow cab is LOS Angeles CA the Maximum KM Travelled from the cab data is 46.8
# - When we have Company Pink cab is Miami FL the Maximum KM Travelled From the cab data is 43.32
# - When we have Company Yellow cab is Miami FL the Maximum KM Travelled from the cab data is 42.92
# - When we have Company Pink cab is Nashville TN the Maximum KM Travelled From the cab data is 36.58
# - When we have Company Yellow cab is Nashville TN the Maximum KM Travelled from the cab data is 41.40
# - When we have Company Pink cab is New York NY the Maximum KM Travelled From the cab data is 45.22
# - When we have Company Yellow cab is New York NY the Maximum KM Travelled from the cab data is 46.80
# - When we have Company Pink cab is Orange County the Maximum KM Travelled From the cab data is 39.2
# - When we have Company Yellow cab is Orange County the Maximum KM Travelled from the cab data is 42.4
# - When we have Company Pink cab is Phoenix Az the Maximum KM Travelled from the cab data is 41.3
# - When we have Company Yellow cab is Phoenix Az the Maximum KM Travelled From the cab data is 37.8
# - When we have Company Pink cab is Pittsburgh Pa the Maximum KM Travelled from the cab data is 28.35
# - When we have Company Yellow cab is Pittsburgh Pa the Maximum KM Travelled From the cab data is 38.52
# - When we have Company Pink cab is Sacramento ca the Maximum KM Travelled from the cab data is 47.60
# - When we have Company Yellow cab is Sacramento ca the Maximum KM Travelled From the cab data is 44.84
# - When we have Company Pink cab is San Diego ca the Maximum KM Travelled from the cab data is 44.00
# - When we have Company Yellow cab is San Diego ca the Maximum KM Travelled From the cab data is 46.80
# - When we have Company Pink cab is Seattle WA the Maximum KM Travelled from the cab data is 46.00
# - When we have Company Yellow cab is Seattle WA the Maximum KM Travelled From the cab data is 46.02
# - When we have Company Pink cab is Silicon Valley the Maximum KM Travelled from the cab data is 39.78
# - When we have Company Yellow cab is Silicon Valley the Maximum KM Travelled From the cab data is 43.60
# - When we have Company Pink cab is Tucson AZ the Maximum KM Travelled from the cab data is 39.00
# - When we have Company Yellow cab is Tucson AZ the Maximum KM Travelled From the cab data is 38.88
# - When we have Company Pink cab is Washington DC the Maximum KM Travelled from the cab data is 43.29
# - When we have Company Pink cab is Washington DC the Maximum KM Travelled from the cab data is 45.24

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['KM Travelled'],
            aggfunc='mean')
# Out:
# City        ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Company
# Pink Cab     20.982857    28.8625  20.600000   23.673333  17.765000
# Yellow Cab   20.775238    27.3270  23.066034   22.714134  25.508372
#
# City        DENVER CO  LOS ANGELES CA   MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab       11.870       23.580481  23.008333       24.3800    21.837500
# Yellow Cab     23.082       22.193596  25.984444       23.0975    23.460683
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab        17.290000   25.258000          20.50      29.013333
# Yellow Cab      20.162727   27.385714          24.27      24.600000
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab       22.502586   21.485484       23.528636    14.8675      22.485417
# Yellow Cab     21.878750   25.236087       20.766667    22.5900      22.910183

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Maximum KM Travelled from the cab data is 20.982857
# - when we have Company Yellow cab is Atlanta Ga the Maximum KM Travelled from the cab data is 20.775238
# - When we have Company Pink cab is Austin Tx the Maximum KM Travelled From the cab data is 28.8625
# - When we have Company Yellow cab is Austlin Tx the Maximum KM Travelled from the cab data is 27.3270
# - When we have Company Pink cab is Boston MA the Maximum KM Travelled from the cab data is 20.600000
# - When we have Company Yellow cab is Boston GA the Maximum KM Travelled from the cab data is 23.066034
# - when we have Company Pink cab is Chicago IL the Maximum KM Travelled from the cab data is 23.673333
# - When we have Company Yellow cab is Chicago IL the Maximum KM Travelled From the cab data is 22.714134
# - When we have Company Pink cab is Dallas Tx the Maximum KM Travelled from the cab data is 25.508372
# - When we have Company Yellow cab is Dallas Tx the Maximum KM Travelled from the cab data is 11.870
# - When we have Company Pink cab is Denver CO the Maximum KM Travelled From the cab data is 23.082
# - When we have Company Yellow cab is Denver CO the Maximum KM Travelled from the cab data is 23.580481
# - When we have Company Pink cab is LOS Angeles CA the Maximum KM Travelled From the cab data is 22.193596
# - When we have Company Yellow cab is LOS Angeles CA the Maximum KM Travelled from the cab data is 22.193596
# - When we have Company Pink cab is Miami FL the Maximum KM Travelled From the cab data is 23.008333
# - When we have Company Yellow cab is Miami FL the Maximum KM Travelled from the cab data is 25.984444
# - When we have Company Pink cab is Nashville TN the Maximum KM Travelled From the cab data is 24.3800
# - When we have Company Yellow cab is Nashville TN the Maximum KM Travelled from the cab data is 23.0975
# - When we have Company Pink cab is New York NY the Maximum KM Travelled From the cab data is 21.837500
# - When we have Company Yellow cab is New York NY the Maximum KM Travelled from the cab data is 23.460683
# - When we have Company Pink cab is Orange County the Maximum KM Travelled From the cab data is 17.290000
# - When we have Company Yellow cab is Orange County the Maximum KM Travelled from the cab data is 20.162727
# - When we have Company Pink cab is Phoenix Az the Maximum KM Travelled from the cab data is 25.258000
# - When we have Company Yellow cab is Phoenix Az the Maximum KM Travelled From the cab data is 27.385714
# - When we have Company Pink cab is Pittsburgh Pa the Maximum KM Travelled from the cab data is 20.50
# - When we have Company Yellow cab is Pittsburgh Pa the Maximum KM Travelled From the cab data is 24.27
# - When we have Company Pink cab is Sacramento ca the Maximum KM Travelled from the cab data is 29.013333
# - When we have Company Yellow cab is Sacramento ca the Maximum KM Travelled From the cab data is 24.600000
# - When we have Company Pink cab is San Diego ca the Maximum KM Travelled from the cab data is 22.502586
# - When we have Company Yellow cab is San Diego ca the Maximum KM Travelled From the cab data is 21.485484
# - When we have Company Pink cab is Seattle WA the Maximum KM Travelled from the cab data is 21.485484
# - When we have Company Yellow cab is Seattle WA the Maximum KM Travelled From the cab data is 25.236087
# - When we have Company Pink cab is Silicon Valley the Maximum KM Travelled from the cab data is 23.528636
# - When we have Company Yellow cab is Silicon Valley the Maximum KM Travelled From the cab data is 20766667
# - When we have Company Pink cab is Tucson AZ the Maximum KM Travelled from the cab data is 14.8675
# - When we have Company Yellow cab is Tucson AZ the Maximum KM Travelled From the cab data is 22.5900
# - When we have Company Pink cab is Washington DC the Maximum KM Travelled from the cab data is 22.485417
# - When we have Company Pink cab is Washington DC the Maximum KM Travelled from the cab data is 22.910183

# %% [markdown]
# ### Date of Travel, Company,Cost of Trip

# %%
# Draw the syntax 
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['Cost of Trip'],
            aggfunc='min')
# Out:
# Company         Pink Cab  Yellow Cab
# Date of Travel
# 01/02/2016        21.008     26.4216
# 01/03/2016        36.414     29.7648
# 01/04/2016        25.440     66.1500
# 01/05/2016        85.456     37.8144
# 01/06/2016        20.776     26.9568
# 01/07/2016        55.500     29.1696
# 01/08/2016        50.504     27.9336
# 01/09/2016        25.200     25.3080
# 01/10/2016        22.048     24.4440
# 01/11/2016        45.312     24.2256
# 01/12/2016        57.240     33.4080
# 01/13/2016        33.000     34.5420
# 01/14/2016        19.380     24.4800
# 01/15/2016        33.222     26.9280
# 01/16/2016        51.975     29.2896
# 01/17/2016        62.700     28.9800
# 01/18/2016        49.720     25.9488
# 01/19/2016       316.736    133.5600

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab  the mninimum Cost of Trip from the cab data is 21.008
# - When we have Date of Travel 1/02/2016 is Yellow cab the minimum Cost of Trip from the cabe data is 26.4216
# - When we have Date of Travel 1/03/2016 is Pink cab the minimum Cost of Trip from the cabe data is 29.7648
# - when we have Date of Travel 1/03/2016 is yellow Cab the minimum Cost of Trip from the cab data is 25.440
# - when we have Date of Travel 1/04/2016 is Pink Cab the minimum Cost of Trip from the cab data is 25.440
# - when we have Date of Travel 1/04/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 66.1500
# - when we have Date of Travel 1/05/2016 is Pink Cab the minimum Cost of Trip from the cab data is 85.456
# - when we have Date of Travel 1/05/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 37.8144
# - when we have Date of Travel 1/06/2016 is Pink Cab the minimum Cost of Trip from the cab data is 20.776
# - when we have Date of Travel 1/06/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 26.9568
# - when we have Date of Travel 1/07/2016 is Pink Cab the minimum Cost of Trip from the cab data is 55.500
# - when we have Date of Travel 1/07/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 29.1696
# - when we have Date of Travel 1/08/2016 is Pink Cab the minimum Cost of Trip from the cab data is 50.504
# - when we have Date of Travel 1/08/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 27.9336
# - when we have Date of Travel 1/09/2016 is Pink Cab the minimum Cost of Trip from the cab data is 25.200
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the minimum Cost of Trip from the cab data is 25.3080
# - when we have Date of Travel 1/10/2016 is Pink Cab the minimum Cost of Trip from the cab data is 22.048
# - when we have Date of Travel 1/10/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 24.4440
# - when we have Date of Travel 1/11/2016 is Pink Cab the minimum Cost of Trip from the cab data is 45.312
# - when we have Date of Travel 1/11/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 24.2256
# - when we have Date of Travel 1/12/2016 is Pink Cab the minimum Cost of Trip from the cab data is 57.240
# - when we have Date of Travel 1/12/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 33.4080
# - when we have Date of Travel 1/13/2016 is Pink Cab the minimum Cost of Trip from the cab data is 33.000
# - when we have Date of Travel 1/13/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 34.5420
# - when we have Date of Travel 1/14/2016 is Pink Cab the minimum Cost of Trip from the cab data is 19.380
# - when we have Date of Travel 1/14/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 24.4800
# - when we have Date of Travel 1/15/2016 is Pink Cab the minimum Cost of Trip from the cab data is 33.222
# - when we have Date of Travel 1/15/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 26.9280
# - when we have Date of Travel 1/16/2016 is Pink Cab the minimum Cost of Trip from the cab data is 51.975
# - when we have Date of Travel 1/16/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 29.2896
# - when we have Date of Travel 1/17/2016 is Pink Cab the minimum Cost of Trip from the cab data is 62.700
# - when we have Date of Travel 1/17/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 28.9800
# - when we have Date of Travel 1/18/2016 is Pink Cab the minimum Cost of Trip from the cab data is 49.720
# - when we have Date of Travel 1/18/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 25.9488
# - when we have Date of Travel 1/19/2016 is Pink Cab the minimum Cost of Trip from the cab data is 316.736
# - when we have Date of Travel 1/19/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 133.5600

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['Cost of Trip'],
            aggfunc='max')
# Out:
# Company         Pink Cab  Yellow Cab
# Date of Travel
# 01/02/2016       542.800    629.2800
# 01/03/2016       492.804    634.8888
# 01/04/2016       369.963    554.1120
# 01/05/2016       471.861    623.7504
# 01/06/2016       427.140    547.5600
# 01/07/2016       453.492    624.0312
# 01/08/2016       463.203    612.4800
# 01/09/2016       502.550    662.6880
# 01/10/2016       520.144    645.6960
# 01/11/2016       475.200    581.1264
# 01/12/2016       418.950    597.2688
# 01/13/2016       542.400    579.0720
# 01/14/2016       510.510    668.1600
# 01/15/2016       475.894    616.8960
# 01/16/2016       444.015    596.7360
# 01/17/2016       467.856    611.1840
# 01/18/2016       497.280    623.3760
# 01/19/2016       316.736    354.1248

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab  the mninimum Cost of Trip from the cab data is 542.800
# - When we have Date of Travel 1/02/2016 is Yellow cab the minimum Cost of Trip from the cabe data is 629.2800
# - When we have Date of Travel 1/03/2016 is Pink cab the minimum Cost of Trip from the cabe data is 492.804
# - when we have Date of Travel 1/03/2016 is yellow Cab the minimum Cost of Trip from the cab data is 634.8888
# - when we have Date of Travel 1/04/2016 is Pink Cab the minimum Cost of Trip from the cab data is 369.963
# - when we have Date of Travel 1/04/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 554.1120
# - when we have Date of Travel 1/05/2016 is Pink Cab the minimum Cost of Trip from the cab data is 471.861
# - when we have Date of Travel 1/05/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 623.7504
# - when we have Date of Travel 1/06/2016 is Pink Cab the minimum Cost of Trip from the cab data is 427.140
# - when we have Date of Travel 1/06/2016 is Yellow Cab the minimum Cost of Trip from the cab data is 547.5600
# - when we have Date of Travel 1/07/2016 is Pink Cab the minimum Cost of Trip from the cab data is 453.492
# - when we have Date of Travel 1/07/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 624.0312
# - when we have Date of Travel 1/08/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 463.203
# - when we have Date of Travel 1/08/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 612.4800
# - when we have Date of Travel 1/09/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 502.550
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the Maximum Cost of Trip from the cab data is 662.6880
# - when we have Date of Travel 1/10/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 520.144
# - when we have Date of Travel 1/10/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 645.6960
# - when we have Date of Travel 1/11/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 475.200
# - when we have Date of Travel 1/11/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 581.1264
# - when we have Date of Travel 1/12/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 418.950
# - when we have Date of Travel 1/12/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 597.2688
# - when we have Date of Travel 1/13/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 542.400
# - when we have Date of Travel 1/13/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 579.0720
# - when we have Date of Travel 1/14/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 510.510
# - when we have Date of Travel 1/14/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 668.1600
# - when we have Date of Travel 1/15/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 475.894
# - when we have Date of Travel 1/15/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 616.8960
# - when we have Date of Travel 1/16/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 444.015
# - when we have Date of Travel 1/16/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 596.7360
# - when we have Date of Travel 1/17/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 467.856
# - when we have Date of Travel 1/17/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 611.1840
# - when we have Date of Travel 1/18/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 497.280
# - when we have Date of Travel 1/18/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 623.3760
# - when we have Date of Travel 1/19/2016 is Pink Cab the Maximum Cost of Trip from the cab data is 316.736
# - when we have Date of Travel 1/19/2016 is Yellow Cab the Maximum Cost of Trip from the cab data is 133.5600

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['Cost of Trip'],
            aggfunc='mean')
# Out:
# Company           Pink Cab  Yellow Cab
# Date of Travel
# 01/02/2016      220.711195  308.298206
# 01/03/2016      283.745154  297.791438
# 01/04/2016      209.369750  292.212800
# 01/05/2016      293.406833  350.219620
# 01/06/2016      244.374304  291.110972
# 01/07/2016      240.438250  293.463846
# 01/08/2016      294.568238  277.711013
# 01/09/2016      262.555965  303.727979
# 01/10/2016      236.718478  309.680579
# 01/11/2016      205.057000  305.127687
# 01/12/2016      233.340091  303.018895
# 01/13/2016      242.941500  295.684986
# 01/14/2016      252.611552  290.710911
# 01/15/2016      257.258667  325.104279
# 01/16/2016      228.906733  331.155461
# 01/17/2016      224.160045  314.649266
# 01/18/2016      188.329706  281.216045
# 01/19/2016      316.736000  278.620650

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab  the Average Cost of Trip from the cab data is 220.711195
# - When we have Date of Travel 1/02/2016 is Yellow cab the Average Cost of Trip from the cabe data is 308.298206
# - When we have Date of Travel 1/03/2016 is Pink cab the Average Cost of Trip from the cabe data is 283.745154
# - when we have Date of Travel 1/03/2016 is yellow Cab the Average Cost of Trip from the cab data is 297.791438
# - when we have Date of Travel 1/04/2016 is Pink Cab the Average Cost of Trip from the cab data is 209.369750
# - when we have Date of Travel 1/04/2016 is Yellow Cab the Average Cost of Trip from the cab data is 292.212800
# - when we have Date of Travel 1/05/2016 is Pink Cab the Average Cost of Trip from the cab data is 293.406833
# - when we have Date of Travel 1/05/2016 is Yellow Cab the Average Cost of Trip from the cab data is 350.219620
# - when we have Date of Travel 1/06/2016 is Pink Cab the Average Cost of Trip from the cab data is 244.374304
# - when we have Date of Travel 1/06/2016 is Yellow Cab the Average Cost of Trip from the cab data is 291.110972
# - when we have Date of Travel 1/07/2016 is Pink Cab the Average Cost of Trip from the cab data is 240.438250
# - when we have Date of Travel 1/07/2016 is Yellow Cab the Average Cost of Trip from the cab data is 293.463846
# - when we have Date of Travel 1/08/2016 is Pink Cab the Average Cost of Trip from the cab data is 294.568238
# - when we have Date of Travel 1/08/2016 is Yellow Cab the Average Cost of Trip from the cab data is 277.711013
# - when we have Date of Travel 1/09/2016 is Pink Cab the Average Cost of Trip from the cab data is 262.555965
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the Average Cost of Trip from the cab data is 303.727979
# - when we have Date of Travel 1/10/2016 is Pink Cab the Average Cost of Trip from the cab data is 236.718478
# - when we have Date of Travel 1/10/2016 is Yellow Cab the Average Cost of Trip from the cab data is 309.680579
# - when we have Date of Travel 1/11/2016 is Pink Cab the Average Cost of Trip from the cab data is 205.057000
# - when we have Date of Travel 1/11/2016 is Yellow Cab the Average Cost of Trip from the cab data is 305.127687
# - when we have Date of Travel 1/12/2016 is Pink Cab the Average Cost of Trip from the cab data is 303.018895
# - when we have Date of Travel 1/13/2016 is Pink Cab the Average Cost of Trip from the cab data is 242.941500
# - when we have Date of Travel 1/13/2016 is Yellow Cab the Average Cost of Trip from the cab data is 295.684986
# - when we have Date of Travel 1/14/2016 is Pink Cab the Average Cost of Trip from the cab data is 252.611552
# - when we have Date of Travel 1/14/2016 is Yellow Cab the Average Cost of Trip from the cab data is 290.710911
# - when we have Date of Travel 1/15/2016 is Pink Cab the Average Cost of Trip from the cab data is 257.258667
# - when we have Date of Travel 1/15/2016 is Yellow Cab the Average Cost of Trip from the cab data is 325.104279
# - when we have Date of Travel 1/16/2016 is Pink Cab the Average Cost of Trip from the cab data is 228.906733
# - when we have Date of Travel 1/16/2016 is Yellow Cab the Average Cost of Trip from the cab data is 331.155461
# - when we have Date of Travel 1/17/2016 is Pink Cab the Average Cost of Trip from the cab data is 224.160045
# - when we have Date of Travel 1/17/2016 is Yellow Cab the Average Cost of Trip from the cab data is 314.649266
# - when we have Date of Travel 1/18/2016 is Pink Cab the Average Cost of Trip from the cab data is 188.329706
# - when we have Date of Travel 1/18/2016 is Yellow Cab the Average Cost of Trip from the cab data is 281.216045
# - when we have Date of Travel 1/19/2016 is Pink Cab the Average Cost of Trip from the cab data is 316.736000
# - when we have Date of Travel 1/19/2016 is Yellow Cab the Average Cost of Trip from the cab data is 278.620650

# %% [markdown]
# ### Date of Travel,City,Cost of Trip

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['Cost of Trip'],
            aggfunc='min')
# Out:
# City            ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Date of Travel
# 01/02/2016         97.6320        NaN   106.3104     26.4216    71.4000
# 01/03/2016         29.7888   318.4272    39.3984     74.9000    30.6360
# 01/04/2016             NaN   220.2144   219.8208     89.3664        NaN
# 01/05/2016        435.6000        NaN        NaN     60.0000   190.4448
# 01/06/2016        151.1136   349.6284    20.7760     55.7520    98.2800
# 01/07/2016         63.0240   377.8900    76.4750     57.9072   246.4000
# 01/08/2016        267.6240        NaN    41.0868     30.6360   183.7440
# 01/09/2016         61.2720        NaN    42.3576     25.3080    52.9008
# 01/10/2016         24.4800   343.4400    46.3680     23.8960    33.7050
# 01/11/2016        112.4736        NaN   126.5400     60.6048    49.4900
# 01/12/2016         82.3680        NaN    57.2400     33.4080   101.6064
# 01/13/2016        164.5280        NaN    55.2160     50.1600        NaN
# ...

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['Cost of Trip'],
            aggfunc='max')
# Out:
# City            ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Date of Travel
# 01/02/2016        545.4540        NaN   564.5952    526.6800   585.5040
# 01/03/2016        305.9100   475.2000   524.6748    482.0400   634.8888
# 01/04/2016             NaN   220.2144   219.8208    554.1120        NaN
# 01/05/2016        435.6000        NaN        NaN    623.7504   562.3680
# 01/06/2016        530.7120   349.6284   392.0400    547.5600   485.2224
# 01/07/2016        596.4192   377.8900   584.7660    574.9440   530.8056
# 01/08/2016        313.6350        NaN   499.9176    532.3560   554.5920
# 01/09/2016        539.2128        NaN   612.6120    616.8960   559.8240
# 01/10/2016        305.9000   453.7656   568.8072    634.9344   536.2560
# 01/11/2016        366.2820        NaN   551.0928    581.1264   248.9616
# 01/12/2016         82.3680        NaN   560.2800    511.7544   109.9104
# 01/13/2016        270.0480        NaN   435.4560    542.4000        NaN
# ...

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['Cost of Trip'],
            aggfunc='mean')
# Out:
# City            ATLANTA GA  AUSTIN TX   BOSTON MA  CHICAGO IL   DALLAS TX  \
# Date of Travel
# 01/02/2016      357.827280        NaN  357.033440  264.386674  306.133429
# 01/03/2016      161.937000   401.8208  256.382760  269.851916  298.509000
# 01/04/2016             NaN   220.2144  219.820800  337.094400         NaN
# 01/05/2016      435.600000        NaN         NaN  475.886000  408.310400
# 01/06/2016      318.859440   349.6284  215.934622  318.092008  300.268000
# 01/07/2016      280.112933   377.8900  301.007433  304.886228  387.648400
# 01/08/2016      290.629500        NaN  330.060229  242.031230  369.168000
# 01/09/2016      310.133829        NaN  316.589736  284.564030  330.964920
# 01/10/2016      159.799000   416.3868  295.485219  267.338796  290.376360
# 01/11/2016      224.886150        NaN  314.707543  324.811168  117.111867
# 01/12/2016       82.368000        NaN  283.749750  255.550240  105.758400
# ...

# %% [markdown]
# ### Company, City,Cost of Trip

# %%
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['Cost of Trip'],
            aggfunc='min')
# Out:
# City        ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Company
# Pink Cab        63.024     40.352    20.7760      23.896     33.705
# Yellow Cab      24.480    162.426    26.9568      24.444     30.636
#
# City        DENVER CO  LOS ANGELES CA  MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab      45.3120         19.3800   64.8420       60.6900        21.42
# Yellow Cab    25.9488         24.2256   57.0096      110.9184        25.08
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab          35.8020      48.840        150.535        129.272
# Yellow Cab        43.5564     161.784         40.788         34.542
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab           23.60     21.0080          44.688     58.320          30.30
# Yellow Cab         24.48     29.7648          45.600     86.184          43.47

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Minimum Cost of Trip  is 63.024
# - when we have Company Yellow cab is Atlanta Ga the Minimum Cost of Trip  is 24.480
# - When we have Company Pink cab is Austin Tx the Minimum Cost of Trip  is 40.352
# - When we have Company Yellow cab is Austlin Tx the Minimum Cost of Trip  is 162.426
# - When we have Company Pink cab is Boston MA the Minimum Cost of Trip is 20.7760
# - When we have Company Yellow cab is Boston GA the Minimum Cost of Trip is 26.9568
# - when we have Company Pink cab is Chicago IL the Minimum Cost of Trip is 23.896
# - When we have Company Yellow cab is Chicago IL the Minimum Cost of Trip is 24.444
# - When we have Company Pink cab is Dallas Tx the Minimum Cost of Trip is 33.705
# - When we have Company Yellow cab is Dallas Tx the Minimum Cost of Trip is 30.636
# - When we have Company Pink cab is Denver CO the Minimum Cost of Trip is 45.3120
# - When we have Company Yellow cab is Denver CO the Minimum Cost of Trip is 25.9488
# - When we have Company Pink cab is LOS Angeles CA the Minimum Cost of Trip is 19.3800
# - When we have Company Yellow cab is LOS Angeles CA the Minimum Cost of Trip is 24.2256
# - When we have Company Pink cab is Miami FL the Minimum Cost of Trip is 64.8420
# - When we have Company Yellow cab is Miami FL the Minimum Cost of Trip is 57.0096
# - When we have Company Pink cab is Nashville TN the Minimum Cost of Trip is 60.6900
# - When we have Company Yellow cab is Nashville TN the Minimum Cost of Trip is 110.9184
# - When we have Company Pink cab is New York NY the Minimum Cost of Trip is 21.42
# - When we have Company Yellow cab is New York NY the Minimum Cost of Trip is 25.08
# - When we have Company Pink cab is Orange County the Minimum Cost of Trip is 35.8020
# - When we have Company Yellow cab is Orange County the Minimum Cost of Trip is 43.5564
# - When we have Company Pink cab is Phoenix Az the Minimum Cost of Trip is 48.840
# - When we have Company Yellow cab is Phoenix Az the Minimum Cost of Tripis 161.784
# - When we have Company Pink cab is Pittsburgh Pa the Minimum Cost of Trip is 150.535
# - When we have Company Yellow cab is Pittsburgh Pa the Minimum Cost of Trip is 40.788
# - When we have Company Pink cab is Sacramento ca the Minimum Cost of Trip is 129.272
# - When we have Company Yellow cab is Sacramento ca the Minimum Cost of Trip  is 34.542
# - When we have Company Pink cab is San Diego ca the Minimum Cost of Trip is 23.60
# - When we have Company Yellow cab is San Diego ca the Minimum Cost of Trip is 24.48
# - When we have Company Pink cab is Seattle WA the Minimum Cost of Trip is 21.0080
# - When we have Company Yellow cab is Seattle WA the Minimum Cost of Trip 29.7648
# - When we have Company Pink cab is Silicon Valley the Minimum Cost of Trip is 44.688
# - When we have Company Yellow cab is Silicon Valley the Minimum Cost of Trip is 45.600
# - When we have Company Pink cab is Tucson AZ the Minimum Cost of Trip is 58.320
# - When we have Company Yellow cab is Tucson AZ the Minimum Cost of Trip is 86.184
# - When we have Company Pink cab is Washington DC the Minimum Cost of Trip is 30.30
# - When we have Company Pink cab is Washington DC the Minimum Cost of Trip is 43.47

# %%
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['Cost of Trip'],
            aggfunc='max')
# Out:
# City        ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Company
# Pink Cab      472.4160   475.2000    520.144    542.4000   426.6880
# Yellow Cab    596.4192   591.7632    612.612    634.9344   634.8888
#
# City        DENVER CO  LOS ANGELES CA  MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab     331.7600          542.80   467.856       418.140      498.104
# Yellow Cab   592.0296          668.16   554.778       506.736      645.696
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab          446.880    463.7520       334.5300       480.7600
# Yellow Cab        605.472    516.5568       526.9536       597.2688
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab         476.064     469.200        477.3600    401.700        466.200
# Yellow Cab       662.688     607.464        569.4624    536.544        607.392

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Maximum Cost of Trip  is 472.4160
# - when we have Company Yellow cab is Atlanta Ga the Maximum Cost of Trip  is 596.4192
# - When we have Company Pink cab is Austin Tx the Maximum Cost of Trip  is 475.2000
# - When we have Company Yellow cab is Austlin Tx the Maximum Cost of Trip  is 591.7632
# - When we have Company Pink cab is Boston MA the Maximum Cost of Trip is 520.144
# - When we have Company Yellow cab is Boston GA the Maximum Cost of Trip is 612.612
# - when we have Company Pink cab is Chicago IL the Maximum Cost of Trip is 542.4000
# - When we have Company Yellow cab is Chicago IL the Maximum Cost of Trip is 634.9344
# - When we have Company Pink cab is Dallas Tx the Maximum Cost of Trip is 426.6880
# - When we have Company Yellow cab is Dallas Tx the Maximum Cost of Trip is 634.8888
# - When we have Company Pink cab is Denver CO the Maximum Cost of Trip is 331.7600
# - When we have Company Yellow cab is Denver CO the Maximum Cost of Trip is 592.0296
# - When we have Company Pink cab is LOS Angeles CA the Maximum Cost of Trip is 542.80
# - When we have Company Yellow cab is LOS Angeles CA the Maximum Cost of Trip is 668.16
# - When we have Company Pink cab is Miami FL the Maximum Cost of Trip is 467.856
# - When we have Company Yellow cab is Miami FL the Maximum Cost of Trip is 554.778
# - When we have Company Pink cab is Nashville TN the Maximum Cost of Trip is 418.140
# - When we have Company Yellow cab is Nashville TN the Maximum Cost of Trip is 506.736
# - When we have Company Pink cab is New York NY the Maximum Cost of Trip is 498.104
# - When we have Company Yellow cab is New York NY the Maximum Cost of Trip is 645.696
# - When we have Company Pink cab is Orange County the Maximum Cost of Trip is 446.880
# - When we have Company Yellow cab is Orange County the Maximum Cost of Trip is 605.472
# - When we have Company Pink cab is Phoenix Az the Maximum Cost of Trip is 463.7520
# - When we have Company Yellow cab is Phoenix Az the Maximum Cost of Tripis 516.5568
# - When we have Company Pink cab is Pittsburgh Pa the Maximum Cost of Trip is 334.5300
# - When we have Company Yellow cab is Pittsburgh Pa the Maximum Cost of Trip is 526.9536
# - When we have Company Pink cab is Sacramento ca the Maximum Cost of Trip is 480.7600
# - When we have Company Yellow cab is Sacramento ca the Maximum Cost of Trip  is 597.2688
# - When we have Company Pink cab is San Diego ca the Maximum Cost of Trip is 476.064
# - When we have Company Yellow cab is San Diego ca the Maximum Cost of Trip is 662.688
# - When we have Company Pink cab is Seattle WA the Maximum Cost of Trip is 469.200
# - When we have Company Yellow cab is Seattle WA the Maximum Cost of Trip is 607.464
# - When we have Company Pink cab is Silicon Valley the Maximum Cost of Trip is 477.3600
# - When we have Company Yellow cab is Silicon Valley the Maximum Cost of Trip is 569.4624
# - When we have Company Pink cab is Tucson AZ the Maximum Cost of Trip is 401.700
# - When we have Company Yellow cab is Tucson AZ the Maximum Cost of Trip is 536.544
# - When we have Company Pink cab is Washington DC the Maximum Cost of Trip is 466.200
# - When we have Company Pink cab is Washington DC the Maximum Cost of Trip is 607.392

# %%
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['Cost of Trip'],
            aggfunc='mean')

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Average Cost of Trip  is 225.623429
# - when we have Company Yellow cab is Atlanta Ga the Average Cost of Trip  is 274.596771
# - When we have Company Pink cab is Austin Tx the Average Cost of Trip  is 314.33250
# - When we have Company Yellow cab is Austlin Tx the Average Cost of Trip  is 360.55548
# - When we have Company Pink cab is Boston MA the Average Cost of Trip is 228.893759
# - When we have Company Yellow cab is Boston GA the Maximum Cost of Trip is 304.961979
# - when we have Company Pink cab is Chicago IL the Average Cost of Trip is 262.443767
# - When we have Company Yellow cab is Chicago IL the Average Cost of Trip is 300.080353
# - When we have Company Pink cab is Dallas Tx the Average Cost of Trip is 194.001667
# - When we have Company Yellow cab is Dallas Tx the Average Cost of Trip is 335.782381
# - When we have Company Pink cab is Denver CO the Average Cost of Trip is 134.251286
# - When we have Company Yellow cab is Denver CO the Average Cost of Trip is 304.410800
# - When we have Company Yellow cab is LOS Angeles CA the v Cost of Trip is 261.729077
# - When we have Company Pink cab is Miami FL the Average Cost of Trip is 291.704075
# - When we have Company Yellow cab is Miami FL the Average Cost of Trip is 248.075167
# - When we have Company Pink cab is Nashville TN the Average Cost of Trip is 334.547733
# - When we have Company Yellow cab is Nashville TN the Average Cost of Trip is 265.9016
# - When we have Company Pink cab is New York NY the Average Cost of Trip is 290.1453
# - When we have Company Yellow cab is New York NY the Average Cost of Trip is 240.692288
# - When we have Company Pink cab is Orange County the Average Cost of Trip is 309.381246
# - When we have Company Yellow cab is Orange County the Average Cost of Trip is 192.495000
# - When we have Company Pink cab is Phoenix Az the Average Cost of Trip is 263.588182
# - When we have Company Yellow cab is Phoenix Az the Average Cost of Tripis 266.5394
# - When we have Company Pink cab is Pittsburgh Pa the Average Cost of Trip is 364.7904
# - When we have Company Yellow cab is Pittsburgh Pa the Average Cost of Trip is 242.5325
# - When we have Company Pink cab is Sacramento ca the Average Cost of Trip is 324.0312
# - When we have Company Yellow cab is Sacramento ca the Average Cost of Trip  is 310.859500
# - When we have Company Pink cab is San Diego ca the Average Cost of Trip is 330.882343
# - When we have Company Yellow cab is San Diego ca the Average Cost of Trip is 246.140448
# - When we have Company Pink cab is Seattle WA the Average Cost of Trip is 291.683850
# - When we have Company Yellow cab is Seattle WA the Average Cost of Trip is 236.014000
# - When we have Company Pink cab is Silicon Valley the Average Cost of Trip is 333.312078
# - When we have Company Yellow cab is Silicon Valley the Average Cost of Trip is 264.251000
# - When we have Company Pink cab is Tucson AZ the Average Cost of Trip is 274.549422
# - When we have Company Yellow cab is Tucson AZ the Average Cost of Trip is 153.28850
# - When we have Company Pink cab is Washington DC the Average Cost of Trip is 301.01328
# - When we have Company Pink cab is Washington DC the Average Cost of Trip is 242.400583

# %% [markdown]
# ### Date of Travel, Company,Price Charged

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['Price Charged'],
            aggfunc='min')

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab the mninimum Price Charged is 24.79
# - When we have Date of Travel 1/02/2016 is Yellow cab the minimum Price Charged is 45.47
# - When we have Date of Travel 1/03/2016 is Pink cab the minimum Price Charged is 70.50
# - when we have Date of Travel 1/03/2016 is yellow Cab the minimum Price Charged is 58.93
# - when we have Date of Travel 1/04/2016 is Pink Cab the minimum Price Chargedis 42.07
# - when we have Date of Travel 1/04/2016 is Yellow Cab the minimum Price Charged is 114.66
# - when we have Date of Travel 1/05/2016 is Pink Cab the minimum Price Charged is 135.93
# - when we have Date of Travel 1/05/2016 is Yellow Cab the minimum Price Charged is 85.54
# - when we have Date of Travel 1/06/2016 is Pink Cab the minimum Price Charged is 27.71
# - when we have Date of Travel 1/06/2016 is Yellow Cab the minimum Price Charged is 39.03
# - when we have Date of Travel 1/07/2016 is Pink Cab the minimum Price Charged is 72.43
# - when we have Date of Travel 1/07/2016 is Yellow Cab the minimum Price Charged is 60.82
# - when we have Date of Travel 1/08/2016 is Pink Cab the minimum Price Charged is 78.29
# - when we have Date of Travel 1/08/2016 is Yellow Cab the minimum Price Charged is 41.64
# - when we have Date of Travel 1/09/2016 is Pink Cab the minimum Price Charged is 35.34
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the minimum Price Charged is 40.23
# - when we have Date of Travel 1/10/2016 is Pink Cab the minimum Price Charged 22.20
# - when we have Date of Travel 1/10/2016 is Yellow Cab the minimum Price Charged is 40.26
# - when we have Date of Travel 1/11/2016 is Pink Cab the minimum Price Charged is 34.98
# - when we have Date of Travel 1/11/2016 is Yellow Cab the minimum Price Charged is 43.24
# - when we have Date of Travel 1/12/2016 is Pink Cab the minimum Price Charged is 43.25
# - when we have Date of Travel 1/12/2016 is Yellow Cab the minimum Price Chargedis 45.50
# - when we have Date of Travel 1/13/2016 is Pink Cab the minimum Price Charged is 40.99
# - when we have Date of Travel 1/13/2016 is Yellow Cab the minimum Price Charged is 70.26
# - when we have Date of Travel 1/14/2016 is Pink Cab the minimum Price Charged is 27.55
# - when we have Date of Travel 1/14/2016 is Yellow Cab the minimum Price Charged is 36.55
# - when we have Date of Travel 1/15/2016 is Pink Cab the minimum Price Chargeda is 26.52
# - when we have Date of Travel 1/15/2016 is Yellow Cab the minimum Price Charged is 32.97
# - when we have Date of Travel 1/16/2016 is Pink Cab the minimum Price Charged is 71.06
# - when we have Date of Travel 1/16/2016 is Yellow Cab the minimum Price Charged is 42.86
# - when we have Date of Travel 1/17/2016 is Pink Cab the minimum Price Chargedis 83.74
# - when we have Date of Travel 1/17/2016 is Yellow Cab the minimum Price Charged is 42.81
# - when we have Date of Travel 1/18/2016 is Pink Cab the minimum Price Charged is 42.10
# - when we have Date of Travel 1/18/2016 is Yellow Cab the minimum Price Charged is 57.56
# - when we have Date of Travel 1/19/2016 is Pink Cab the minimum Price Charged is 296.76
# - when we have Date of Travel 1/19/2016 is Yellow Cab the minimum Price Charged is 157.63

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['Price Charged'],
            aggfunc='max')

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab the Maximum  Price Charged is 997.84
# - When we have Date of Travel 1/02/2016 is Yellow cab the Maximum Price Charged is 1519.56
# - When we have Date of Travel 1/03/2016 is Pink cab the Maximum Price Charged is 1022.59
# - when we have Date of Travel 1/03/2016 is yellow Cab the Maximum Price Charged is 1544.45
# - when we have Date of Travel 1/04/2016 is Pink Cab the Maximum Price Charged is 546.69
# - when we have Date of Travel 1/04/2016 is Yellow Cab the Maximum Price Charged is 1053.13
# - when we have Date of Travel 1/05/2016 is Pink Cab the Maximum Price Charged is 720.24
# - when we have Date of Travel 1/05/2016 is Yellow Cab the Maximum Price Charged is 1332.31
# - when we have Date of Travel 1/06/2016 is Pink Cab the Maximum Price Charged is 744.45
# - when we have Date of Travel 1/06/2016 is Yellow Cab the Maximum Price Charged is 1174.32
# - when we have Date of Travel 1/07/2016 is Pink Cab the Maximum Price Charged is 589.01
# - when we have Date of Travel 1/07/2016 is Yellow Cab the Maximum Price Chargedis 1540.61
# - when we have Date of Travel 1/08/2016 is Pink Cab the Maximum Price Charged is 791.75
# - when we have Date of Travel 1/08/2016 is Yellow Cab the Maximum Price Charged is 1246.69
# - when we have Date of Travel 1/09/2016 is Pink Cab the Maximum Price Charged is 849.37
# - when we have Date of Travel 1/09/2016 is Yekkow Cab the Maximum Price Charged is 1437.40
# - when we have Date of Travel 1/10/2016 is Pink Cab the Maximum Price Charged is 886.72
# - when we have Date of Travel 1/10/2016 is Yellow Cab the Maximum Price Charged is 1503.74
# - when we have Date of Travel 1/11/2016 is Pink Cab the Maximum Price Charged is 678.48
# - when we have Date of Travel 1/11/2016 is Yellow Cab the Maximum Price Charged is 1181.35
# - when we have Date of Travel 1/12/2016 is Pink Cab the Maximum Price Charged is 554.83
# - when we have Date of Travel 1/12/2016 is Yellow Cab the Maximum Price Chargedis 1261.33
# - when we have Date of Travel 1/13/2016 is Pink Cab the Maximum Price Charged is 551.82
# - when we have Date of Travel 1/13/2016 is Yellow Cab the Maximum Price Charged is 921.34
# - when we have Date of Travel 1/14/2016 is Pink Cab the Maximum Price Charged is 663.42
# - when we have Date of Travel 1/14/2016 is Yellow Cab the Maximum Price Charged is 1146.90
# - when we have Date of Travel 1/15/2016 is Pink Cab the Maximum Price Charged is 640.81
# - when we have Date of Travel 1/15/2016 is Yellow Cab the Maximum Price Charged is 1206.99
# - when we have Date of Travel 1/16/2016 is Pink Cab the Maximum Price Charged is 659.28
# - when we have Date of Travel 1/16/2016 is Yellow Cab the Maximum Price Charged is 1156.93
# - when we have Date of Travel 1/17/2016 is Pink Cab the Maximum Price Charged is 564.43
# - when we have Date of Travel 1/17/2016 is Yellow Cab the Maximum Price Charged is 1184.23
# - when we have Date of Travel 1/18/2016 is Pink Cab the Maximum Price Charged is 643.13
# - when we have Date of Travel 1/18/2016 is Yellow Cab the Maximum Price Charged is 1021.91
# - when we have Date of Travel 1/19/2016 is Pink Cab the Maximum Price Charged is 296.76
# - when we have Date of Travel 1/19/2016 is Yellow Cab the Maximum Price Charged is 785.77

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['Company'], values=df_cab_data['Price Charged'],
            aggfunc='mean')

# %% [markdown]
# ### Interpretation
# - when we have Date of Travel 1/02/2016 is Pink Cab the Average Price Charged is 338.014146
# - When we have Date of Travel 1/02/2016 is Yellow cab the Average Price Charged is 631.838500
# - When we have Date of Travel 1/03/2016 is Pink cab the Average Price Charged is 487.987115
# - when we have Date of Travel 1/03/2016 is yellow Cab the Average Price Charged is 602.946429
# - when we have Date of Travel 1/04/2016 is Yellow Cab the Average Price Charged is 316.517500
# - when we have Date of Travel 1/04/2016 is Pink Cab the Average Price Charged is 466.031905
# - when we have Date of Travel 1/05/2016 is Yellow Cab the Average Price Charged is 417.633333
# - when we have Date of Travel 1/05/2016 is Pink Cab the Average Price Charged is 626.759024
# - when we have Date of Travel 1/06/2016 is Yellow Cab the Average Price Chargedis 345.982174
# - when we have Date of Travel 1/06/2016 is Pink Cab the Average Price Charged is 508.127791
# - when we have Date of Travel 1/07/2016 is Yellow Cab the Average Price Charged is 292.713333
# - when we have Date of Travel 1/07/2016 is Pink Cab the Average Price Charged is 517.285726
# - when we have Date of Travel 1/08/2016 is Yekkow Cab the Average Price Charged is 402.074762
# - when we have Date of Travel 1/08/2016 is Pink Cab the Average Price Charged is 507.793111
# - when we have Date of Travel 1/09/2016 is Yellow Cab the Average Price Charged is 379.829123
# - when we have Date of Travel 1/09/2016 is Pink Cab the Average Price Charged is 555.952146
# - when we have Date of Travel 1/10/2016 is Yellow Cab the Average Price Charged is 342.874030
# - when we have Date of Travel 1/10/2016 is Pink Cab the Average Price Charged is 590.606543
# - when we have Date of Travel 1/11/2016 is Yellow Cab the Average Price Chargedis 269.891538
# - when we have Date of Travel 1/11/2016 is Pink Cab the Average Price Charged is 515.529710
# - when we have Date of Travel 1/12/2016 is Yellow Cab the Average Price Charged is 292.727727
# - when we have Date of Travel 1/12/2016 is Pink Cab the Average Price Charged is 534.463898
# - when we have Date of Travel 1/13/2016 is Yellow Cab the Average Price Charged is 284.198750
# - when we have Date of Travel 1/13/2016 is Pink Cab the Average Price Charged is 497.698028
# - when we have Date of Travel 1/14/2016 is Yellow Cab the Average Price Charged is 290.222759
# - when we have Date of Travel 1/14/2016 is Pink Cab the Average Price Charged is 494.138421
# - when we have Date of Travel 1/15/2016 is Yellow Cab the Average Price Charged is 304.037500
# - when we have Date of Travel 1/15/2016 is Pink Cab the Average Price Charged is 537.801507
# - when we have Date of Travel 1/16/2016 is Yellow Cab the Average Price Charged is 287.694000
# - when we have Date of Travel 1/16/2016 is Pink Cab the Average Price Charged is 554.220290
# - when we have Date of Travel 1/17/2016 is Yellow Cab the Average Price Charged is 255.455000
# - when we have Date of Travel 1/17/2016 is Pink Cab the Average Price Charged is 511.788525
# - when we have Date of Travel 1/18/2016 is Yellow Cab the Average Price Charged is 235.571176
# - when we have Date of Travel 1/18/2016 is Pink Cab the Average Price Charged is 450.671364
# - when we have Date of Travel 1/19/2016 is Yellow Cab the Average Price Charged is 296.760000
# - when we have Date of Travel 1/19/2016 is Pink Cab the Average Price Charged is 499.688750

# %% [markdown]
# ### Date of Travel,City,Price Charged

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['Price Charged'],
            aggfunc='min')
# Out:
# City            ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Date of Travel
# 01/02/2016          125.20        NaN     171.81       48.04     122.42
# 01/03/2016           76.60     576.15      58.93      113.79      63.95
# 01/04/2016             NaN     464.51     306.24      137.07        NaN
# 01/05/2016         1036.84        NaN        NaN      104.76     427.73
# 01/06/2016          358.52     846.41      27.71       84.45      73.43
# 01/07/2016           72.43     466.10     101.39       88.82     175.80
# 01/08/2016          370.95        NaN      55.86       41.64     341.10
# 01/09/2016          111.76        NaN      61.31       40.23      99.97
# 01/10/2016           45.63     532.63      64.75       38.16      36.10
# 01/11/2016          190.52        NaN     158.01       86.65      35.76
# 01/12/2016          126.46        NaN      43.25       45.50     205.51
# 01/13/2016          195.36        NaN      43.07       84.32        NaN
# ...

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['Price Charged'],
            aggfunc='max')
# Out:
# City            ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Date of Travel
# 01/02/2016         1430.64        NaN     971.09     1005.24    1519.56
# 01/03/2016          924.94    1050.10     908.69      847.57    1288.14
# 01/04/2016             NaN     464.51     306.24      721.76        NaN
# 01/05/2016         1036.84        NaN        NaN      879.77    1168.09
# 01/06/2016         1157.08     846.41     470.94      816.65     950.75
# 01/07/2016         1540.61     466.10     770.87      992.12    1147.80
# 01/08/2016          609.50        NaN     703.49      796.70    1222.08
# 01/09/2016         1412.06        NaN     796.84     1017.20    1273.38
# 01/10/2016          355.93     978.64     797.59     1002.34    1215.02
# 01/11/2016          756.27        NaN     794.89      871.38     506.77
# 01/12/2016          126.46        NaN     690.59      774.30     210.77
# 01/13/2016          379.31        NaN     424.52      905.31        NaN
# ...

# %%
pd.crosstab(index=df_cab_data['Date of Travel'],columns=df_cab_data['City'], values=df_cab_data['Price Charged'],
            aggfunc='mean')
# Out:
# City             ATLANTA GA   AUSTIN TX   BOSTON MA  CHICAGO IL   DALLAS TX  \
# Date of Travel
# 01/02/2016       916.646000         NaN  556.547000  448.855714  613.160000
# 01/03/2016       429.030000  786.043333  421.958000  450.404194  658.235000
# 01/04/2016              NaN  464.510000  306.240000  469.226250         NaN
# 01/05/2016      1036.840000         NaN         NaN  688.131667  849.390000
# 01/06/2016       666.594000  846.410000  295.443333  471.589231  531.696667
# 01/07/2016       594.695000  466.100000  403.576667  462.560690  735.187500
# 01/08/2016       490.225000         NaN  447.421429  370.456500  781.590000
# 01/09/2016       657.510000         NaN  431.525909  484.607541  684.282000
# 01/10/2016       214.757500  712.940000  376.095714  428.747843  631.176000
# 01/11/2016       417.135000         NaN  428.618571  486.731200  193.613333
# 01/12/2016       126.460000         NaN  332.517500  370.722000  208.140000
# ...

# %% [markdown]
# ### Company, City,Price Charged

# %%
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['Price Charged'],
            aggfunc='min')
# Out:
# City        ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Company
# Pink Cab         72.43      73.21      27.71       38.16      35.76
# Yellow Cab       42.86     215.58      32.97       40.23      63.95
#
# City        DENVER CO  LOS ANGELES CA  MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab        34.98           27.55    105.42        114.58        37.18
# Yellow Cab      57.56           43.24    100.59        183.24        48.97
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab            54.40       71.57         198.92         144.58
# Yellow Cab          90.78      351.51          95.53          92.83
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab           35.34       22.20           70.91      94.49          26.52
# Yellow Cab         36.55       54.57           87.66     104.71          59.98

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Minimum Price Charged  is 72.43
# - when we have Company Yellow cab is Atlanta Ga the Minimum Price Charged is 42.86
# - When we have Company Pink cab is Austin Tx the Minimum Price Charged is 73.21
# - When we have Company Yellow cab is Austlin Tx the Minimum Price Charged  is 215.58
# - When we have Company Pink cab is Boston MA the Minimum Price Charged is 27.71
# - When we have Company Yellow cab is Boston GA the Minimum Price Charged is 32.97
# - when we have Company Pink cab is Chicago IL the Minimum Price Charged is 38.16
# - When we have Company Yellow cab is Chicago IL the Minimum Price Charged is 40.23
# - When we have Company Pink cab is Dallas Tx the Minimum Price Charged is 35.76
# - When we have Company Yellow cab is Dallas Tx the Minimum Price Charged is 63.95
# - When we have Company Pink cab is Denver CO the Minimum Price Charged is 34.98
# - When we have Company Yellow cab is Denver CO the Minimum Price Charged is 57.56
# - When we have Company Pink cab is LOS Angeles CA the Minimum Price Charged is 27.55
# - When we have Company Yellow cab is LOS Angeles CA the Minimum Price Charged is 43.24
# - When we have Company Pink cab is Miami FL the Minimum Price Charged is 105.42
# - When we have Company Yellow cab is Miami FL the Minimum Price Charged is 100.59
# - When we have Company Pink cab is Nashville TN the Minimum Price Charged is 114.58
# - When we have Company Yellow cab is Nashville TN the Minimum Price Charged is 183.24
# - When we have Company Pink cab is New York NY the Minimum Price Charged is 37.18
# - When we have Company Yellow cab is New York NY the Minimum Price Charged is 48.97
# - When we have Company Pink cab is Orange County the Minimum Price Charged is 54.40
# - When we have Company Pink cab is Orange County the Minimum Price Charged is 90.78
# - When we have Company Pink cab is Phoenix Az the Minimum Price Charged is 71.57
# - When we have Company Yellow cab is Phoenix Az the Minimum Price Charged is 351.51
# - When we have Company Pink cab is Pittsburgh Pa the Minimum Price Charged is 198.92
# - When we have Company Yellow cab is Pittsburgh Pa the Minimum Price Charged is 95.53
# - When we have Company Pink cab is Sacramento ca the Minimum Price Charged is 144.58
# - When we have Company Pink cab is San Diego ca the Minimum Price Charged is 92.83
# - When we have Company Yellow cab is San Diego ca the Minimum Price Charged is 35.34
# - When we have Company Pink cab is Seattle WA the Minimum Price Charged is 36.55
# - When we have Company Yellow cab is Seattle WA the Minimum Price Charged is 22.20
# - When we have Company Pink cab is Silicon Valley the Minimum Price Charged is 54.57
# - When we have Company Yellow cab is Silicon Valley the Minimum Price Charged is 87.66
# - When we have Company Pink cab is Tucson AZ the Minimum Price Charged is 94.49
# - When we have Company Yellow cab is Tucson AZ the Minimum Price Charged is 104.71
# - When we have Company Pink cab is WASHINGTON DC the Minimum Price Charged is 26.52
# - When we have Company Yellow cab is WASHINGTON DC the Minimum Price Charged is 59.98

# %%
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['Price Charged'],
            aggfunc='max')
# Out:
# City        ATLANTA GA  AUSTIN TX  BOSTON MA  CHICAGO IL  DALLAS TX  \
# Company
# Pink Cab        544.11     576.15     646.06      643.13     416.20
# Yellow Cab     1540.61    1050.10     971.09     1017.20    1519.56
#
# City        DENVER CO  LOS ANGELES CA  MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab       220.26         1022.59    535.83        886.72       705.86
# Yellow Cab    1207.84         1360.81   1072.78       1174.32      1544.45
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab           783.04      761.68         520.10         873.50
# Yellow Cab         891.03     1002.40        1134.12        1261.33
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab          793.63      585.57          685.93     571.77         531.69
# Yellow Cab       1338.75     1344.24         1437.40    1138.99         946.88

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Maximum Price Charged  is 544.11
# - when we have Company Yellow cab is Atlanta Ga the Maximum Price Charged is 1540.61
# - When we have Company Pink cab is Austin Tx the Maximum Price Charged is 576.15
# - When we have Company Yellow cab is Austlin Tx the Maximum Price Charged  is 1050.10
# - When we have Company Pink cab is Boston MA the Maximum Price Charged is 646.06
# - When we have Company Yellow cab is Boston GA the Maximum Price Charged is 971.09
# - when we have Company Pink cab is Chicago IL the Maximum Price Charged is 643.13
# - When we have Company Yellow cab is Chicago IL the Maximum Price Charged is 1017.20
# - When we have Company Pink cab is Dallas Tx the Maximum Price Charged is 416.20
# - When we have Company Yellow cab is Dallas Tx the Maximum Price Charged is 1519.56
# - When we have Company Pink cab is Denver CO the Maximum Price Charged is 220.26
# - When we have Company Yellow cab is Denver CO the Maximum Price Charged is 1207.84
# - When we have Company Pink cab is LOS Angeles CA the Maximum Price Charged is 1022.59
# - When we have Company Yellow cab is LOS Angeles CA the Maximum Price Charged is 1360.81
# - When we have Company Pink cab is Miami FL the Maximum Price Charged is 535.83
# - When we have Company Yellow cab is Miami FL the Maximum Price Charged is 1072.78
# - When we have Company Pink cab is Nashville TN the Maximum Price Charged is 886.72
# - When we have Company Yellow cab is Nashville TN the Maximum Price Charged is 1174.32
# - When we have Company Pink cab is New York NY the Maximum Price Charged is 705.86
# - When we have Company Yellow cab is New York NY the Maximum Price Charged is 1544.45
# - When we have Company Pink cab is Orange County the Maximum Price Charged is 783.04
# - When we have Company Pink cab is Orange County the Maximum Price Charged is 891.03
# - When we have Company Pink cab is Phoenix Az the Maximum Price Charged is 761.68
# - When we have Company Yellow cab is Phoenix Az the Maximum Price Charged is 1002.40
# - When we have Company Pink cab is Pittsburgh Pa the Maximum Price Charged is 761.68
# - When we have Company Yellow cab is Pittsburgh Pa the Maximum Price Charged is 1134.12
# - When we have Company Pink cab is Sacramento ca the Maximum Price Charged is 873.50
# - When we have Company Pink cab is Sacramento ca the Maximum Price Charged is 1261.33
# - When we have Company Pink cab is San Diego ca the Maximum Price Charged is 793.63
# - When we have Company Yellow cab is San Diego ca the Maximum Price Charged is 1338.75
# - When we have Company Pink cab is Seattle WA the Maximum Price Charged is 585.57
# - When we have Company Yellow cab is Seattle WA the Maximum Price Charged is 1344.24
# - When we have Company Pink cab is Silicon Valley the Maximum Price Charged is 685.93
# - When we have Company Yellow cab is Silicon Valley the Maximum Price Charged is 1437.40
# - When we have Company Pink cab is Tucson AZ the Maximum Price Charged is 571.77
# - When we have Company Yellow cab is Tucson AZ the Maximum Price Charged is 1138.99
# - When we have Company Pink cab is WASHINGTON DC the Maximum Price Charged is 531.69
# - When we have Company Yellow cab is WASHINGTON DC the Maximum Price Charged is 946.88

# %%
pd.crosstab(index=df_cab_data['Company'],columns=df_cab_data['City'], values=df_cab_data['Price Charged'],
            aggfunc='mean')
# Out:
# City        ATLANTA GA  AUSTIN TX   BOSTON MA  CHICAGO IL   DALLAS TX  \
# Company
# Pink Cab    265.914286    422.195  250.088276  338.624167  173.017500
# Yellow Cab  594.252619    665.909  403.041897  486.660950  707.625349
#
# City         DENVER CO  LOS ANGELES CA    MIAMI FL  NASHVILLE TN  NEW YORK NY  \
# Company
# Pink Cab    109.084286      452.432212  315.025000       470.382   324.289423
# Yellow Cab  684.514667      540.134532  602.898889       657.185   651.339512
#
# City        ORANGE COUNTY  PHOENIX AZ  PITTSBURGH PA  SACRAMENTO CA  \
# Company
# Pink Cab       299.332222     438.772     359.510000     471.466667
# Yellow Cab     458.968182     657.680     738.696667     654.237143
#
# City        SAN DIEGO CA  SEATTLE WA  SILICON VALLEY  TUCSON AZ  WASHINGTON DC
# Company
# Pink Cab      373.832931  208.489355      370.749545    219.565     246.065000
# Yellow Cab    523.212344  611.309565      632.728148    587.152     434.553476

# %% [markdown]
# ### Interpretation
# - When we have Company Pink cab is ATLANTA GA the Average Price Charged  is 265.914286
# - when we have Company Yellow cab is Atlanta Ga the Average Price Charged is 594.252619
# - When we have Company Pink cab is Austin Tx the Average Price Charged is 422.195
# - When we have Company Yellow cab is Austlin Tx the Average Price Charged  is 665.909
# - When we have Company Pink cab is Boston MA the Average Price Charged is 250.088276
# - When we have Company Yellow cab is Boston GA the Average Price Charged is 403.041897
# - when we have Company Pink cab is Chicago IL the Average Price Charged is 338.624167
# - When we have Company Yellow cab is Chicago IL the Average Price Charged is 338.624167
# - When we have Company Pink cab is Dallas Tx the Average Price Charged is 173.017500
# - When we have Company Yellow cab is Dallas Tx the Average Price Charged is 707.625349
# - When we have Company Pink cab is Denver CO the Average Price Charged is 109.084286
# - When we have Company Yellow cab is Denver CO the Average Price Charged is 684.514667
# - When we have Company Pink cab is LOS Angeles CA the Average Price Charged is 452.432212
# - When we have Company Yellow cab is LOS Angeles CA the Average Price Charged is 540.134532
# - When we have Company Pink cab is Miami FL the Average Price Charged is 315.025000
# - When we have Company Yellow cab is Miami FL the Average Price Charged is 602.898889
# - When we have Company Pink cab is Nashville TN the Average Price Charged is 470.382
# - When we have Company Yellow cab is Nashville TN the Average Price Charged is 657.185
# - When we have Company Pink cab is New York NY the Average Price Charged is 324.289423
# - When we have Company Yellow cab is New York NY the Average Price Charged is 651.339512
# - When we have Company Pink cab is Orange County the Average Price Charged is 299.332222
# - When we have Company Pink cab is Orange County the Average Price Charged is 458.968182
# - When we have Company Pink cab is Phoenix Az the Average Price Charged is 438.772
# - When we have Company Pink cab is Phoenix Az the Average Price Charged is 657.680
# - When we have Company Pink cab is Pittsburgh Pa the Average Price Charged is 359.510000
# - When we have Company Yellow cab is Pittsburgh Pa the Average Price Charged is 738.696667
# - When we have Company Pink cab is Sacramento ca the Average Price Charged is 471.466667
# - When we have Company Pink cab is Sacramento ca the Average Price Charged is 654.237143
# - When we have Company Pink cab is San Diego ca the Average Price Charged is 373.832931
# - When we have Company Yellow cab is San Diego ca the Average Price Charged is 523.212344
# - When we have Company Pink cab is Seattle WA the Average Price Charged is 208.489355
# - When we have Company Yellow cab is Seattle WA the Average Price Charged is 611.309565
# - When we have Company Pink cab is Silicon Valley the Average Price Charged is 370.749545
# - When we have Company Yellow cab is Silicon Valley the Average Price Charged is 632.728148
# - When we have Company Pink cab is Tucson AZ the Average Price Charged is 219.565
# - When we have Company Yellow cab is Tucson AZ the Average Price Charged is 587.152
# - When we have Company Pink cab is WASHINGTON DC the Average Price Charged is 246.065000
# - When we have Company Yellow cab is WASHINGTON DC the Average Price Charged is 434.553476
